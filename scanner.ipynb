# %%
###########################################
# Initialization
###########################################

#Gustav.pak Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_ShadowheartKiss.lsf

import bg3moddinglib as bg3
import os
import shutil
import uuid

root_path = os.getcwd()

if not os.path.isfile(os.path.join(root_path, 'scanner.ipynb')):
    raise RuntimeError(f"Wrong root_path: {root_path}. Please update it to point to a directory containing this notebook.")

e = bg3.bg3_modding_env(os.path.join(root_path, "__scanner__", "env"))
t = bg3.bg3_modding_tool(e)

# %%
scanner = bg3.bg3_object_scanner(t)

scanner.create_voice_lines_index(bg3.SHADOWHEART)
