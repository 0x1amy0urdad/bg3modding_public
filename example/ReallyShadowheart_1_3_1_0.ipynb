# %%
###########################################
# Initialization
###########################################

import bg3moddinglib as bg3
import os
import shutil
import uuid

from typing import Optional

root_path = os.getcwd()

if not os.path.isfile(os.path.join(root_path, 'mod.ipynb')):
    raise RuntimeError(f"Wrong root_path: {root_path}. Please update it such that it points to a directory containing this notebook.")

e = bg3.bg3_modding_env(os.path.join(root_path, "env"))
t = bg3.bg3_modding_tool(e)

review = False

# common functions
def random_uuid() -> str:
    return str(uuid.uuid4())

# %%
##################################
# Meta.lsx and directory layout
##################################

mod_name = 'ReallyShadowheart'
mod_path = os.path.join(e.output_path, mod_name)
os.makedirs(mod_path)
os.makedirs(os.path.join(mod_path, 'Mods', mod_name))
shutil.copy(os.path.join(root_path, 'meta.lsx'), os.path.join(mod_path, 'Mods', mod_name))
shutil.copytree(os.path.join(root_path, "lua", "ScriptExtender"), os.path.join(mod_path, 'Mods', mod_name, "ScriptExtender"))

pass

# %%
#################
# Custom flags
#################

# Kissess
ORI_ShadowheartKiss_StartRandom = '7495e78c-9e70-4ea9-95eb-17fde7f94b7c'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_StartRandom, 'ORI_ShadowheartKiss_StartRandom', 4, 'Shadowheart random kiss start')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartKiss_VersionA = 'f2781286-e51c-443f-b1a3-cea4ba95ccf9'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_VersionA, 'ORI_ShadowheartKiss_VersionA', 4, 'Shadowheart kiss variant A')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartKiss_VersionB = '815a0406-7c85-4107-b704-439320fb7f0b'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_VersionB, 'ORI_ShadowheartKiss_VersionB', 4, 'Shadowheart kiss variant B')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartKiss_VersionC = 'c07bfea6-3d37-48f3-aefc-6eb1749b117f'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_VersionC, 'ORI_ShadowheartKiss_VersionC', 4, 'Shadowheart kiss variant C')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartKiss_VersionD = 'db362653-5649-4f1d-bc43-32b85fd42c0e'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_VersionD, 'ORI_ShadowheartKiss_VersionD', 4, 'Shadowheart kiss variant D')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartKiss_VersionE = 'ec79178f-2c18-4a71-b147-7b254439e5b2'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_VersionE, 'ORI_ShadowheartKiss_VersionE', 4, 'Shadowheart kiss variant E')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartKiss_VersionF = '321d447c-5298-4a5c-82de-f884ba4757d4'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartKiss_VersionF, 'ORI_ShadowheartKiss_VersionF', 4, 'Shadowheart kiss variant F')
t.convert_lsx_to_lsf(lsf)

# Shadowheart needs a night to get her thoughts together
ORI_Shadowheart_AfterParents = '6f8e2b2b-5ffa-4e83-adf7-d80a8e36a8d8'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_Shadowheart_AfterParents, 'ORI_Shadowheart_AfterParents', 4, 'Shadowheart needs a night to get her thoughts together')
t.convert_lsx_to_lsf(lsf)

# ORI_Loot_Viconia flag
Loot_Viconias_Stuff = '550ff254-7218-4e11-9699-17d837da43f8'
lsf = bg3.create_flag_lsf_lsx(mod_path, Loot_Viconias_Stuff, 'Loot_Viconias_Stuff', 4, "Loot Viconia's stuff")
t.convert_lsx_to_lsf(lsf)

# ORI_Shadowheart_State_SmilesWhenHugged
ORI_Shadowheart_State_SmilesWhenHugged = '3486a7e3-97c8-464b-9afa-665e8ec981ff'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_Shadowheart_State_SmilesWhenHugged, 'ORI_Shadowheart_State_SmilesWhenHugged', 4, 'Shadowheart is hugged and she smiles')
t.convert_lsx_to_lsf(lsf)

# ORI_Shadowheart_State_HugsEnabled flag
ORI_Shadowheart_State_HugsEnabled = '9402335a-e23e-464b-9c18-fb5fed9eff04'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_Shadowheart_State_HugsEnabled, 'ORI_Shadowheart_State_HugsEnabled', 4, 'Shadowheart was hugged, she liked that and wants more hugs')
t.convert_lsx_to_lsf(lsf)

# ORI_Shadowheart_State_HugReaction
ORI_Shadowheart_State_HugReaction = 'b55cf115-9659-4b46-9150-ae4a261ea0af'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_Shadowheart_State_HugReaction, 'ORI_Shadowheart_State_HugReaction', 4, 'Shadowheart reacts to the first hug when she is not sad')
t.convert_lsx_to_lsf(lsf)


# ORI_ShadowheartMoreOpportunitiesToSlipAway flag
ORI_ShadowheartMoreOpportunitiesToSlipAway = '2f2779cf-4a7b-44ef-8458-d29b48578740'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartMoreOpportunitiesToSlipAway, 'ORI_ShadowheartMoreOpportunitiesToSlipAway', 4, 'Shadowheart says that she hopes for more opportunities to slip away')
t.convert_lsx_to_lsf(lsf)

ORI_ShadowheartAnotherSwimmingLessonReplied = '8942cfa4-550f-482b-8b27-56625dee1c15'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartAnotherSwimmingLessonReplied, 'ORI_ShadowheartAnotherSwimmingLessonReplied', 4, 'Shadowheart replied to a proposal of seizing an opportunity')
t.convert_lsx_to_lsf(lsf)

# ORI_ShadowheartAnotherSwimmingLesson flag
ORI_ShadowheartAnotherSwimmingLesson = '46190b70-0be5-4f11-834c-59b278211de2'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_ShadowheartAnotherSwimmingLesson, 'ORI_ShadowheartAnotherSwimmingLesson', 4, 'Triggers the skinny dipping cutscene one more time')
t.convert_lsx_to_lsf(lsf)

# ORI_State_DontHireDapperDrowPromise flag
ORI_State_DontHireDapperDrowPromise = '6b71d4ba-373d-4332-bd8b-84faeee3d768'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_State_DontHireDapperDrowPromise, 'ORI_State_DontHireDapperDrowPromise', 4, 'This character promised their romantic partner to not hire drow twins')
t.convert_lsx_to_lsf(lsf)

# ORI_State_RejectedDapperDrow flag
ORI_State_RejectedDapperDrow = '0ff9ee19-b9ca-40e1-b67f-f5f172fb83f9'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_State_RejectedDapperDrow, 'ORI_State_RejectedDapperDrow', 4, 'This character made their mind to not hire drow twins')
t.convert_lsx_to_lsf(lsf)

# ORI_State_RejectedDapperDrow3some flag
ORI_State_RejectedDapperDrow3some = 'e9d590df-3c6e-48c5-b19e-7ad3899b4eab'
lsf = bg3.create_flag_lsf_lsx(mod_path, ORI_State_RejectedDapperDrow3some, 'ORI_State_RejectedDapperDrow3some', 4, 'This character and their partners made their minds to not hire drow twins')
t.convert_lsx_to_lsf(lsf)

Speaker_Approval_Set_To_Zero = 'add81fd0-0641-45d3-8020-29098ccc22d7'
lsf = bg3.create_flag_lsf_lsx(mod_path, Speaker_Approval_Set_To_Zero, 'Speaker_Approval_Set_To_Zero', 4, "Reduce Tav's approval with the speaker to naught")
t.convert_lsx_to_lsf(lsf)

Speaker_Approval_Set_To_Neutral = '42a1da52-ccf5-46a0-954d-8f1c53dd20b6'
lsf = bg3.create_flag_lsf_lsx(mod_path, Speaker_Approval_Set_To_Neutral, 'Speaker_Approval_Set_To_Neutral', 4, "Reduce Tav's approval with the speaker to a neutral level")
t.convert_lsx_to_lsf(lsf)

Speaker_Approval_Set_To_Low = '2701e07a-73a2-4b96-9951-9080555f3f8f'
lsf = bg3.create_flag_lsf_lsx(mod_path, Speaker_Approval_Set_To_Low, 'Speaker_Approval_Set_To_Low', 4, "Reduce Tav's approval with the speaker to a low level")
t.convert_lsx_to_lsf(lsf)

Speaker_Approval_Set_To_VeryLow = 'c80bad74-7669-4989-a912-106fd2ed4cd9'
lsf = bg3.create_flag_lsf_lsx(mod_path, Speaker_Approval_Set_To_VeryLow, 'Speaker_Approval_Set_To_VeryLow', 4, "Reduce Tav's approval with the speaker to a very low level")
t.convert_lsx_to_lsf(lsf)

Shadowheart_BreakUp_Notification_Start = 'd20cc281-6ed6-4e9b-bad5-28d403a2b0af'
lsf = bg3.create_flag_lsf_lsx(mod_path, Shadowheart_BreakUp_Notification_Start, 'Shadowheart_BreakUp_Notification_Start', 4, "Tav did something stupid and Shadowheart broke up with them")
t.convert_lsx_to_lsf(lsf)

Shadowheart_BreakUp_Notification_Finish = '80a1a14e-f831-4b3f-815a-684dc15f77e7'
lsf = bg3.create_flag_lsf_lsx(mod_path, Shadowheart_BreakUp_Notification_Finish, 'Shadowheart_BreakUp_Notification_Finish', 4, "Shadowheart told Tav she has broken up with them")
t.convert_lsx_to_lsf(lsf)

pass

# %%
#########
# Loca
#########

content = {
    "h06a5cd66g501bg402bgb1e3g41bd32d9ca18": (1, "Others seem quite tired, they'll be asleep soon. Don't you think we could seize the opportunity?"),
    "h0d2027f1g386eg45bbg8a6ag7ab77f651a6c": (1, "A lot's changed since then. More than I ever thought was possible."),
    "h22d5d4fegda81g4379g9e0cge6ff376a3252": (1, "I want to be by your side."),
    "h4e692070gf12fg40e1g9b36ge64802670e20": (1, "Wait, I don't want to lose you... I want to be with you..."),
    "h55a00408g3549g4916g96d9g0837ef055041": (1, "Only if you kiss me."),
    "h5def25a4gf970g4dadgbb68gec13e203facc": (1, "I'm just trying to get you jealous, my love. Of course I wasn't going to hire any of them."),
    "h694c1b90g4377g41b0gb07dg4a108f59fa65": (1, "I do not serve Shar anymore. Nor the Mother Superior."),
    "h6d9862b7g728fg4822ga5f3g658e9bfc16d3": (1, "What do you mean?"),
    "h7b905a4fgda7dg4417g9c24g768f4ef486e4": (1, "While it's a fascinating prospect, I'd like you all to myself..."),
    "h86f0612cg5ed6g47e6gb6aeg9076005d52a0": (1, "Don't treat me like an idiot, please!"),
    "h9635e41bge285g4f12gb61bg13692d55fba6": (1, "I didn't realize your feel this way. I want to be with you... Forget I ever said anything."),
    "h9a474f8dg36b3g4089gbf4aga01c55224234": (1, "Surely you wouldn't mind if I had a bit of fun? I am my own person, after all."),
    "h9b00b4fbgd0e0g4bbcgadc0gdbea99682ab5": (1, "It's difficult to put into words... I can't remember the last time I sought to confide in someone like this - maybe I never have, for all I know. But now it just feels... right."),
    "ha7011b9bge49bg4abcg8ccdg73f26b37aae3": (1, "I'm happy. I mean, how could I not be? I have you."),
    "ha0b56eb6gbc0bg4535g97efga2b7c2671c58": (1, "&lt;i&gt;Loot her belongings whlie she helplessly lies on the ground.&lt;/i&gt;"),
    "hc0077229g09edg4ed4gb446g6e6f48cf2363": (1, "Your father is right. This is the only way to free your family from Shar's curse and stop the pain."),
    "hf070d2bag8b3cg4918ga17dg7f009caa75dc": (1, "I am free to do whatever I want. Leave, if you have a problem with that."),
    "hf278c5d2g81beg46abgaa45g649a20dfeb09": (1, "Our relationship was... fleeting. I want to move on.")
}

xml = bg3.game_object_factory.create_loca_xml_file(os.path.join(mod_path, "Localization", "English"), "ReallyShadowheart", content)

loca = t.convert_xml_to_loca(xml)
if review:
    loca_xml = t.convert_loca_to_xml(loca)

# %%
############################################################
# 3ed74f063c6042dc83f6f034cb47c679.lsf
############################################################

# Copy wem, gr2 and ffxanim files
src_path = os.path.join(root_path, "loca", "Localization")
dest_path = os.path.join(mod_path, bg3.translate_path('Mods/Gustav/Localization'))
shutil.copytree(src_path, dest_path)

# Patch voice metadata
lsf = t.unpack('Localization/VoiceMeta', 'Mods/Gustav/Localization/English/Soundbanks/3ed74f063c6042dc83f6f034cb47c679.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
sb = bg3.bg3_game_object_soundbank(lsx)
sb.add_voice_metadata(bg3.et.fromstring("""
<node id="VoiceTextMetaData">
    <attribute id="MapKey" type="FixedString" value="h7b905a4fgda7dg4417g9c24g768f4ef486e4" />
    <children>
        <node id="MapValue">
            <attribute id="Codec" type="FixedString" value="VORBIS" />
            <attribute id="Length" type="float" value="4.801" />
            <attribute id="Priority" type="FixedString" value="P1_StoryDialog" />
            <attribute id="Source" type="FixedString" value="v3ed74f063c6042dc83f6f034cb47c679_h7b905a4fgda7dg4417g9c24g768f4ef486e4.wem" />
        </node>
    </children>
</node>
"""))
sb.add_voice_metadata(bg3.et.fromstring("""
<node id="VoiceTextMetaData">
    <attribute id="MapKey" type="FixedString" value="h86f0612cg5ed6g47e6gb6aeg9076005d52a0" />
    <children>
        <node id="MapValue">
            <attribute id="Codec" type="FixedString" value="VORBIS" />
            <attribute id="Length" type="float" value="3.001" />
            <attribute id="Priority" type="FixedString" value="P1_StoryDialog" />
            <attribute id="Source" type="FixedString" value="v3ed74f063c6042dc83f6f034cb47c679_h86f0612cg5ed6g47e6gb6aeg9076005d52a0.wem" />
        </node>
    </children>
</node>
"""))
sb.add_voice_metadata(bg3.et.fromstring("""
<node id="VoiceTextMetaData">
    <attribute id="MapKey" type="FixedString" value="h0d2027f1g386eg45bbg8a6ag7ab77f651a6c" />
    <children>
        <node id="MapValue">
            <attribute id="Codec" type="FixedString" value="VORBIS" />
            <attribute id="Length" type="float" value="4.334" />
            <attribute id="Priority" type="FixedString" value="P1_StoryDialog" />
            <attribute id="Source" type="FixedString" value="v3ed74f063c6042dc83f6f034cb47c679_h0d2027f1g386eg45bbg8a6ag7ab77f651a6c.wem" />
        </node>
    </children>
</node>
"""))
sb.add_voice_metadata(bg3.et.fromstring("""
<node id="VoiceTextMetaData">
    <attribute id="MapKey" type="FixedString" value="ha7011b9bge49bg4abcg8ccdg73f26b37aae3" />
    <children>
        <node id="MapValue">
            <attribute id="Codec" type="FixedString" value="VORBIS" />
            <attribute id="Length" type="float" value="5.317" />
            <attribute id="Priority" type="FixedString" value="P1_StoryDialog" />
            <attribute id="Source" type="FixedString" value="v3ed74f063c6042dc83f6f034cb47c679_ha7011b9bge49bg4abcg8ccdg73f26b37aae3.wem" />
        </node>
    </children>
</node>
"""))
sb.add_voice_metadata(bg3.et.fromstring("""
<node id="VoiceTextMetaData">
    <attribute id="MapKey" type="FixedString" value="h9b00b4fbgd0e0g4bbcgadc0gdbea99682ab5" />
    <children>
        <node id="MapValue">
            <attribute id="Codec" type="FixedString" value="VORBIS" />
            <attribute id="Length" type="float" value="14.938" />
            <attribute id="Priority" type="FixedString" value="P1_StoryDialog" />
            <attribute id="Source" type="FixedString" value="v3ed74f063c6042dc83f6f034cb47c679_h9b00b4fbgd0e0g4bbcgadc0gdbea99682ab5.wem" />
        </node>
    </children>
</node>
"""))



# Save patched data
patched_lsx = sb.save_to(os.path.join(mod_path, 'Mods/Gustav/Localization/English/Soundbanks/3ed74f063c6042dc83f6f034cb47c679.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
#######################################################
# ShadowHeart_InParty2_Nested_ShadowCurseChapter.lsf
#######################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_ShadowCurseChapter.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# speaker slot indexes
slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)


##########################################################################
# IMPOSSIBLE is now POSSIBLE
# New dialog options after Shadowheart dyes her hair in silver white
##########################################################################

jump_to_root_node_uuid = '3e1e7d54-8fc6-4de1-975e-817981f42e99'
dialog_root_node_uuid = 'ef74288f-a1c5-4544-9bf1-35bbcd6097a1'
d.add_dialog_node(bg3.create_jump_dialog_node(jump_to_root_node_uuid, dialog_root_node_uuid))

d.patch_dialog_node_flags('05f1dc75-6e4c-1233-6322-09dbc4c5e2ad', checkflags=[])
d.patch_dialog_node_flags('016fd279-fba7-4e1d-6e53-a0cc6722bdd6', checkflags=[])

d.patch_dialog_append_child('ae117f4d-742f-4521-f6dc-324dc614d3ed', jump_to_root_node_uuid)
d.patch_dialog_append_child('2ff576fb-4b4c-0add-52b0-d1d4aae037c5', jump_to_root_node_uuid)
d.patch_dialog_append_child('30d599f0-3da4-85e3-86fb-9d299b65f9d8', jump_to_root_node_uuid)


##########################################################################
# IMPOSSIBLE is now POSSIBLE
# Hug her after she spares Nightsong (at the Thorm mausoleum entrance)
##########################################################################

shadowheart_approval_40_true = bg3.create_flag_group('Object', ((bg3.FLAG_Approval_AtLeast_40_For_Sp2, True, slot_idx_shadowheart),))
shadowheart_hugs_enabled_false = ORI_Shadowheart_State_HugsEnabled
racist_tag_group = bg3.create_flag_group('Tag', (
    (bg3.TAG_SHORT, False, slot_idx_tav),
    (bg3.TAG_DWARF, False, slot_idx_tav),
    (bg3.TAG_DRAGONBORN, False, slot_idx_tav),
))


hug_her_node_uuid = 'a6e353d2-caa1-4cc0-cb7d-3a0abc6f2bd3'

d.patch_dialog_node_flags(hug_her_node_uuid, checkflags=[shadowheart_approval_40_true, racist_tag_group])


###########################################################################
# IMPOSSIBLE is now POSSIBLE
# Hug her when talking after she spares Nightsong (companion dialog)
# If Shadowheart was already hugged, this one won't appear in the dialog
###########################################################################

hug_her_node_uuid = '77d47cd7-91e5-f569-f50e-1e3bf23e10fb'

flag_group = bg3.create_flag_group('Object', (
    (bg3.FLAG_Approval_AtLeast_40_For_Sp2, True, slot_idx_shadowheart),
    (ORI_Shadowheart_State_SmilesWhenHugged, False, slot_idx_shadowheart),
))

d.patch_dialog_node_flags(hug_her_node_uuid, checkflags=[flag_group, racist_tag_group])
d.patch_dialog_remove_child('022fc6c6-7b3a-e80c-a2fa-81743e94f9a1', hug_her_node_uuid)
d.patch_dialog_append_child('022fc6c6-7b3a-e80c-a2fa-81743e94f9a1', hug_her_node_uuid, index=0)


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_ShadowCurseChapter.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
##########################################
# CAMP_Shadowheart_DaughterTears_SD.lsf
##########################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Camp/SoloDreams/CAMP_Shadowheart_DaughterTears_SD.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# speaker slot indexes
slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)

shadowheart_hugs_enabled_group = bg3.create_flag_group('Object', (
    (ORI_Shadowheart_State_HugsEnabled, True, slot_idx_shadowheart),
    (ORI_Shadowheart_State_SmilesWhenHugged, True, slot_idx_shadowheart)
))

#
# Enable hugs when Shadowhurt is hugged in this cutscene
#

# 'Embrace her', parents not saved
d.patch_dialog_node_flags('315b082c-97cb-34be-3e9b-7b70c9b79b65', setflags=[shadowheart_hugs_enabled_group])
d.patch_dialog_node_flags('39baeaf3-3d49-d4af-d83f-f9bf40455bbe', setflags=[shadowheart_hugs_enabled_group])
d.patch_dialog_node_flags('602bfbe9-c61b-56d9-5c73-3d7086a0c0e1', setflags=[shadowheart_hugs_enabled_group])
d.patch_dialog_node_flags('6bd93424-91db-d2fc-b0f4-41a11b8535b1', setflags=[shadowheart_hugs_enabled_group])
d.patch_dialog_node_flags('d75095a4-ecad-4899-f5c5-99fe0a896fb4', setflags=[shadowheart_hugs_enabled_group])
d.patch_dialog_node_flags('ec90059f-b14f-2344-2a6a-1c450374f488', setflags=[shadowheart_hugs_enabled_group])

# 'That's not true', saved parents
d.patch_dialog_node_flags('ba46c188-dd97-d6dc-4637-4317e194630b', setflags=[shadowheart_hugs_enabled_group])

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Camp/SoloDreams/CAMP_Shadowheart_DaughterTears_SD.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
#############################################################
# Dialog:   ShadowHeart_InParty2_Nested_ShadowheartHug.lsf
# Timeline: ShadowHeart_InParty2_Nested_ShadowheartHug.lsf
# Both files are copied from a local directory
#############################################################

# Copy the dialog
d_dest_dir = os.path.join(mod_path, 'Mods', 'GustavDev', 'Story', 'DialogsBinary', 'Companions')
os.makedirs(d_dest_dir, exist_ok=True)
d_dest_lsx = os.path.join(d_dest_dir, 'ShadowHeart_InParty2_Nested_ShadowheartHug.lsf.lsx')
d_src_lsx = os.path.join(root_path, 'lsx', 'Dialog_ShadowHeart_InParty2_Nested_ShadowheartHug.lsf.lsx')
shutil.copy(d_src_lsx, d_dest_lsx)

# Save patched timeline
lsf = t.convert_lsx_to_lsf(d_dest_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(lsf)


# Copy the timeline
tl_dest_dir = os.path.join(mod_path, 'Public', 'GustavDev', 'Timeline', 'Generated')
os.makedirs(tl_dest_dir, exist_ok=True)
tl_dest_lsx = os.path.join(tl_dest_dir, 'ShadowHeart_InParty2_Nested_ShadowheartHug.lsf.lsx')
tl_src_lsx = os.path.join(root_path, 'lsx', 'Timeline_ShadowHeart_InParty2_Nested_ShadowheartHug.lsf.lsx')
shutil.copy(tl_src_lsx, tl_dest_lsx)


# Save patched timeline
lsf = t.convert_lsx_to_lsf(tl_dest_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(lsf)

# %%
######################################
# ShadowHeart_Recruitment_Beach.lsf
######################################

##########################################################################
# Shadowheart on the beach won't be so appreciative after Tav saves her
##########################################################################
lsf = t.unpack('Gustav', 'Mods/Gustav/Story/DialogsBinary/Companions/ShadowHeart_Recruitment_Beach.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# replace +10 with +3
dialog_node = d.get_dialog_node('b24c2a6c-9a76-30c2-8a78-5263283b7ff9')
approval_rating_attribute = dialog_node.find('attribute[@id="ApprovalRatingID"]')
bg3.to_compact_string(approval_rating_attribute)
approval_rating_attribute.set('value', 'c9644ed9-830d-4234-abf2-8ca972f51240')

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/Gustav/Story/DialogsBinary/Companions/ShadowHeart_Recruitment_Beach.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
#########################################
# WYR_DapperDrow_SiblingsThreeWay.lsf
#########################################

#########################################
# Drow siblings pt 2: dialog changes
#########################################

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Act3/Wyrm/WYR_DapperDrow_SiblingsThreeWay.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# speaker slot indexes
slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)

# flags
shadowheart_enemy_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),))
shadowheart_chosen_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_SharPath, True, None),))
tav_partnered_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),))
tav_partnered_false = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, False, slot_idx_tav),))
tav_brokenup_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_WasPartneredWithShadowheart, True, slot_idx_tav),))
shadowheart_react_to_breakup_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_HandledBreakupWithShadowheart, True, slot_idx_tav),))
really_shadowheart_true = bg3.create_flag_group('Tag', ((bg3.TAG_REALLY_SHADOWHEART, True, slot_idx_shadowheart),))
shadowheart_goes_to_camp = bg3.create_flag_group('Object', ((bg3.FLAG_OriginRemoveFromPartyAfterDialog, True, slot_idx_shadowheart),))
tav_promise_true = bg3.create_flag_group('Object', ((ORI_State_DontHireDapperDrowPromise, True, slot_idx_shadowheart),))
tav_promise_false = bg3.create_flag_group('Object', ((ORI_State_DontHireDapperDrowPromise, False, slot_idx_shadowheart),))
tav_rejected_drow_3some_true = bg3.create_flag_group('Object', ((ORI_State_RejectedDapperDrow3some, True, slot_idx_tav),))
tav_rejected_drow_3some_false = bg3.create_flag_group('Object', ((ORI_State_RejectedDapperDrow3some, False, slot_idx_tav),))
tav_rejected_drow_true = bg3.create_flag_group('Object', ((ORI_State_RejectedDapperDrow, True, slot_idx_tav),))
tav_rejected_drow_false = bg3.create_flag_group('Object', ((ORI_State_RejectedDapperDrow, False, slot_idx_tav),))

set_zero_approval_true = bg3.create_flag_group('Object', ((Speaker_Approval_Set_To_Zero, True, slot_idx_shadowheart),))
set_neutral_approval_true = bg3.create_flag_group('Object', ((Speaker_Approval_Set_To_Neutral, True, slot_idx_shadowheart),))
set_low_approval_true = bg3.create_flag_group('Object', ((Speaker_Approval_Set_To_Low, True, slot_idx_shadowheart),))
set_very_low_approval_true = bg3.create_flag_group('Object', ((Speaker_Approval_Set_To_VeryLow, True, slot_idx_shadowheart),))

#
# Selune Shadowheart always rejects 3some with drows
#
d.patch_dialog_node_flags('42eabadc-bf51-6129-f4f7-e79718020fef', checkflags=[shadowheart_enemy_of_shar_true, tav_partnered_true])
d.patch_dialog_tagged_text('42eabadc-bf51-6129-f4f7-e79718020fef', "h7b905a4fgda7dg4417g9c24g768f4ef486e4", "1")

#
# Shar Shadowheart always agrees to 3some with drows
#
d.patch_dialog_node_flags('4d6c4b25-54b3-d965-9b1d-4240b4d32c09', checkflags=[shadowheart_chosen_of_shar_true, tav_partnered_true])


# dialog uuids
entry_point_node_uuid = '1248ea3a-a035-4944-80f2-b4d3a3752486'
just_like_that_node_uuid = '1f836a58-db44-4b04-8f97-6a9a0361324a'
deception_node_uuid = '20ae75a9-5abd-4b10-b233-3e867dbaf39d'
deception_success_node_uuid = '3f1e941d-77e1-4625-9612-dfd81f0403b9'
deception_failure_node_uuid = 'a1ba021c-571e-43bf-8022-9c3db48c9897'
persuasion_node_uuid = '2bd1be3b-7b34-4ef1-96e6-58a6813cf153'
persuasion_success_node_uuid = '44601422-dbc0-4df1-964e-0b32d9c594f4'
persuasion_failure_node_uuid = '73a44813-57d7-4c86-bc0f-6133ef0ffa93'
lets_drop_this_node_uuid = '7d411d40-89d2-4e4d-b773-8a6c05a22016'
cut_you_loose_node_uuid = 'aa037df5-0825-4f52-8cbf-6783c29df1f3'
dont_do_this_again_node_uuid = '5a598edd-3495-4240-84c7-3e2178f698a0'
bad_liar_node_uuid = '91265082-8a28-4233-b22b-654c2a7656d6'
best_leave_me_alone_uuid = 'f2e1df94-dc62-4981-849c-53bf84eed103'
now_leave_me_alone_uuid = '194e0965-3a7a-4238-b2eb-e5e403e8a4c5'
your_affections_drifted_uuid = '3258a7bb-a84a-44d9-be22-116089156432'
i_am_free_uuid = '9fb11096-33d8-4c30-9eef-3fe7b142b46f'
i_dont_want_to_lose_you_uuid = '56ba2b98-5d0a-4dbe-b5e4-081c85f5bd2c'
your_new_beau_uuid = '35a4a0c9-74c6-4f28-befd-686e3eaec7fb'
spare_lover_uuid = '1bdb3c57-d180-47d1-8eb0-23c5cf08f0cc'
way_to_end_things_uuid = '4b9bf0a2-4058-4a7e-8b6b-9649990fc814'
what_that_could_mean_uuid = '7f30d6cf-1481-4db1-8510-3435005813b9'
arent_dear_friends_uuid = 'ceacb4b7-6db1-4952-8a00-e4fad3ec0e78'


original_node_uuid = 'b7f42923-a360-e758-3504-43b90a2354de'

d.patch_dialog_node_flags(
    original_node_uuid,
    [
        bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_SharPath, True, None),)),
        bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),)),
    ])

entry_point_node = bg3.create_standard_dialog_node(
    entry_point_node_uuid,
    slot_idx_shadowheart,
    [just_like_that_node_uuid, your_affections_drifted_uuid, original_node_uuid],
    '', '', '')
d.add_dialog_node(entry_point_node)

just_like_that_node = bg3.create_standard_dialog_node(
    just_like_that_node_uuid,
    slot_idx_shadowheart,
    [persuasion_node_uuid, deception_node_uuid, lets_drop_this_node_uuid],
    'h656ea716g6c7fg4810g9a40g7a4faf11bd91', # Just like that...? I thought we had something special. Something lasting.
    '3',
    '55e69838-4af2-4a52-be86-c5e6485d29f1',
    checkflags=[shadowheart_enemy_of_shar_true, tav_partnered_true, really_shadowheart_true, tav_promise_false])
d.add_dialog_node(just_like_that_node)

lets_drop_this_node = bg3.create_standard_dialog_node(
    lets_drop_this_node_uuid,
    slot_idx_tav,
    [cut_you_loose_node_uuid],
    'hfd18944dg9b68g4093ga62bg4718589a098a', # Forget I said anything. Let's drop this.
    '1',
    '7e963b60-1e25-4fcd-8af4-47130cc4a240',
    constructor='TagQuestion',
    setflags=[tav_rejected_drow_true])
d.add_dialog_node(lets_drop_this_node)

cut_you_loose_node = bg3.create_standard_dialog_node(
    cut_you_loose_node_uuid,
    slot_idx_shadowheart,
    [],
    'ha090154fg5825g4e2bg8e91g6f160fa5e992', # Fine. But understand that I'll cut you loose the moment I have to.
    '1',
    '0d8e6962-27a3-92bb-0522-a6590c72af0c',
    setflags=[tav_promise_true],
    end_node=True)
d.add_dialog_node(cut_you_loose_node)


deception_success_node = bg3.create_dice_roll_result_node(deception_success_node_uuid, True, dont_do_this_again_node_uuid)
d.add_dialog_node(deception_success_node)
deception_failure_node = bg3.create_dice_roll_result_node(deception_failure_node_uuid, False, bad_liar_node_uuid)
d.add_dialog_node(deception_failure_node)
deception_node = bg3.create_dice_roll_dialog_node(
    deception_node_uuid,
    slot_idx_tav,
    "Wisdom",
    "Deception",
    bg3.DC_Act3_Hard,
    deception_success_node_uuid,
    deception_failure_node_uuid,
    'h5def25a4gf970g4dadgbb68gec13e203facc', # I'm just teasing you. Of course I wasn't going to hire any of them.
    '1',
    'ec405887-641b-431b-b942-92d1c6fe95dd')
d.add_dialog_node(deception_node)

dont_do_this_again_node = bg3.create_standard_dialog_node(
    dont_do_this_again_node_uuid,
    slot_idx_shadowheart,
    [],
    'h6f3bfd2agf0d5g4e74g9420g1e59d78b5047', # At least you're honest. Don't do that again.
    '1',
    '1343f68f-94af-ec93-736e-5d07859e00a0',
    setflags=[tav_promise_true],
    end_node=True)
d.add_dialog_node(dont_do_this_again_node)

bad_liar_node = bg3.create_standard_dialog_node(
    bad_liar_node_uuid,
    slot_idx_shadowheart,
    [best_leave_me_alone_uuid],
    'h52b584b2g870cg4fe6gaf65g16ac985c7657', # You're a bad liar. And perhaps an untrustworthy ally.
    '1',
    'b631bf6f-d8f7-4a17-8a51-44cfe877a23d',
    setflags=[tav_promise_true, set_zero_approval_true])
d.add_dialog_node(bad_liar_node)

best_leave_me_alone = bg3.create_standard_dialog_node(
    best_leave_me_alone_uuid,
    slot_idx_shadowheart,
    [],
    'hb7c3b03bg7d22g41dag989dgae8d9c2223f4', # Best if you leave me alone, for now.
    '1',
    '7c5abb1c-405b-46a5-99d9-1e027dae99ec',
    setflags=[shadowheart_goes_to_camp],
    end_node=True)
d.add_dialog_node(best_leave_me_alone)


persuasion_success_node = bg3.create_dice_roll_result_node(persuasion_success_node_uuid, True, spare_lover_uuid)
d.add_dialog_node(persuasion_success_node)
persuasion_failure_node = bg3.create_dice_roll_result_node(persuasion_failure_node_uuid, False, way_to_end_things_uuid)
d.add_dialog_node(persuasion_failure_node)
persuasion_node = bg3.create_dice_roll_dialog_node(
    persuasion_node_uuid,
    slot_idx_tav,
    "Charisma",
    "Persuasion",
    bg3.DC_Act3_Hard,
    persuasion_success_node_uuid,
    persuasion_failure_node_uuid,
    'h9a474f8dg36b3g4089gbf4aga01c55224234', # Surely you wouldn't mind if I had a bit of fun? I am my own man, after all.
    '1',
    'ec405887-641b-431b-b942-92d1c6fe95dd',
    setflags=[tav_partnered_false, tav_brokenup_true])
d.add_dialog_node(persuasion_node)

spare_lover_node = bg3.create_standard_dialog_node(
    spare_lover_uuid,
    slot_idx_shadowheart,
    [i_dont_want_to_lose_you_uuid],
    'hd3fd298bgb472g4e8bg8e74gaceeb20de6e1', # In truth, I don't think I'd want to be your spare lover. I'd always want more of you than you'd have to spare. Better perhaps to bow out with dignity.
    '3',
    'f3baf849-61c7-4255-9383-ca1a71ac2a0e')
d.add_dialog_node(spare_lover_node)

way_to_end_things_node = bg3.create_standard_dialog_node(
    way_to_end_things_uuid,
    slot_idx_shadowheart,
    [what_that_could_mean_uuid],
    'h80ce62e6g2315g4255g902fg75e92b696ee3', # Well that's one way to end things.
    '3',
    'c42bd961-4dc7-4497-8ac9-1b20ac1e1030',
    setflags=[set_low_approval_true])
d.add_dialog_node(way_to_end_things_node)

what_that_could_mean_node = bg3.create_standard_dialog_node(
    what_that_could_mean_uuid,
    slot_idx_tav,
    [arent_dear_friends_uuid],
    'h6d9862b7g728fg4822ga5f3g658e9bfc16d3', # What could that possibly mean?
    '1',
    '35342a2c-0c39-4e79-ae9e-c1545394630d',
    constructor='TagQuestion')
d.add_dialog_node(what_that_could_mean_node)

arent_dear_friends_node = bg3.create_standard_dialog_node(
    arent_dear_friends_uuid,
    slot_idx_shadowheart,
    [],
    'hd08cebbdgc4acg409ag92a9gcaddaec78634', # We aren't dear friends now, if that's what you're asking.
    '1',
    '5c716a75-ff89-48a5-a541-d416772cf042',
    setflags=[shadowheart_react_to_breakup_true, shadowheart_goes_to_camp],
    end_node=True)
d.add_dialog_node(arent_dear_friends_node)


# When Tav tries to hire drows again, after speaking to Shadowheart
your_affections_drifted_node = bg3.create_standard_dialog_node(
    your_affections_drifted_uuid,
    slot_idx_shadowheart,
    [i_am_free_uuid, i_dont_want_to_lose_you_uuid],
    'h888d9f87g4fddg4df6g83c4g9e7307f9c7dc', # So... I gather your affections have drifted elsewhere. Curious.
    '3',
    'c46f111c-8201-9b3e-aaba-cb8f6539ec18',
    checkflags=[shadowheart_enemy_of_shar_true, tav_partnered_true, really_shadowheart_true, tav_promise_true],
    setflags=[set_low_approval_true])
d.add_dialog_node(your_affections_drifted_node)

i_dont_want_to_lose_you_node = bg3.create_standard_dialog_node(
    i_dont_want_to_lose_you_uuid,
    slot_idx_tav,
    [your_new_beau_uuid],
    'h4e692070gf12fg40e1g9b36ge64802670e20', # Wait, I don't want to lose you... I want to be with you...
    '1',
    'ac781fa5-a4c1-4b60-9f32-f71fb29c0852',
    constructor='TagQuestion',
    setflags=[tav_partnered_false, tav_brokenup_true])
d.add_dialog_node(i_dont_want_to_lose_you_node)

i_am_free_node = bg3.create_standard_dialog_node(
    i_am_free_uuid,
    slot_idx_tav,
    [now_leave_me_alone_uuid],
    'hf070d2bag8b3cg4918ga17dg7f009caa75dc', # I am free to do whatever I want. Leave, if you have a problem with that.
    '1',
    '9c26edff-a16b-4907-89a1-593ce588ffa8',
    constructor='TagQuestion',
    setflags=[tav_partnered_false, tav_brokenup_true])
d.add_dialog_node(i_am_free_node)

now_leave_me_alone_node = bg3.create_standard_dialog_node(
    now_leave_me_alone_uuid,
    slot_idx_shadowheart,
    [],
    'habcc14b2g5065g4b7dg8f22gc39494c34f5e', # Now leave me alone.
    '1',
    'c46f111c-8201-9b3e-aaba-cb8f6539ec18',
    setflags=[shadowheart_react_to_breakup_true, shadowheart_goes_to_camp],
    end_node=True)
d.add_dialog_node(now_leave_me_alone_node)
    
your_new_beau_node = bg3.create_standard_dialog_node(
    your_new_beau_uuid,
    slot_idx_shadowheart,
    [],
    'h45bb0963g86ccg4633gb227gb944064b9b0d', # Oh don't be like that - you've made your bed, now go roll around in it with your new beau.
    '3',
    '638dbd55-1d5a-49d4-ba38-b4e4fb7b9858',
    setflags=[shadowheart_react_to_breakup_true, shadowheart_goes_to_camp],
    end_node=True)
d.add_dialog_node(your_new_beau_node)


# put the new dialog tree into the conversation
d.delete_child_dialog_node('8c62a0da-1341-e527-91d9-9fe9a960cd47', original_node_uuid)
d.insert_child_dialog_node('8c62a0da-1341-e527-91d9-9fe9a960cd47', 0, entry_point_node_uuid)

# recurrent reactions to drow twins
td = d.get_dialog_node('8c62a0da-1341-e527-91d9-9fe9a960cd47')
bg3.remove_node_attribute(td, 'transitionmode')


# if Tav has made his mind to not hire drows, suppress TagQuestions
dialog_uuids=[
    '49b95aec-c693-2332-1874-9aa1a65d37f4', # I'd like to hire your services, my lady.
    '18138b2a-618f-28dc-7b62-90a7dfb46135', # I want to hire you, beautiful lad.
    'fccddc42-f0a1-e4e0-18d2-4e2c68dbdd0a'  # I would like to spend time with you, lady Nym.
]
for dialog_uuid in dialog_uuids:
    td = d.get_dialog_node(dialog_uuid)
    tn = bg3.get_node_children(td, 'checkflags')[0]
    bg3.add_xml_node(tn, tav_rejected_drow_false)

td = d.get_dialog_node('650c0d75-3e1a-06f2-63c1-09f4554b4adb') # I would like to hire both of you. And I hope my partner will join us as well.
tn = bg3.get_node_children(td, 'checkflags')[0]
bg3.add_xml_node(tn, tav_rejected_drow_3some_false)

dialog_uuids=[
    '37e7cf82-ed52-4b7d-b903-38237b6ab604', # I feel the same way.
    '0b4912e4-fd26-7785-6e7a-ce1852138fb0' # Forget I said anything. Let's drop this.
]
for dialog_uuid in dialog_uuids:
    td = d.get_dialog_node(dialog_uuid)
    tn = bg3.get_node_children(td, 'setflags')[0]
    bg3.add_xml_node(tn, tav_rejected_drow_3some_true)


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Act3/Wyrm/WYR_DapperDrow_SiblingsThreeWay.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
#############################################################
# Timeline: WYR_DapperDrow_SiblingsThreeWay.lsf
#############################################################

def create_effect_components_drow_twins(tl_obj: bg3.bg3_game_object_dialog_timeline, start: float, end: float, phase_index: str, node_uuid: str, emotions: tuple, cool_down: float=0.3) -> None:
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_voice(
            random_uuid(), start, end, phase_index, node_uuid, '83f6b986-2ef6-40b5-b9d9-d6f74b09949e', is_snapped_to_end=True, is_mirrored=True, peanut_override=True))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_emotion_event(
            random_uuid(), start, end, phase_index, '83f6b986-2ef6-40b5-b9d9-d6f74b09949e', emotions, is_snapped_to_end=True, peanut_override=True))
    keys = ({
                'Time': ('float', str(start)),
                'InterpolationType': ('uint8', '3'),
                'ShowVisual': ('bool', 'False')
            },
            {
                'Time': ('float', str(end - cool_down)),
                'InterpolationType': ('uint8', '3')                
            })
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_show_visual(
            random_uuid(), start, end, phase_index, '25f367a9-f41f-4598-a5ca-2e6d93d42665', is_snapped_to_end=True, keys=keys))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_show_visual(
            random_uuid(), start, end, phase_index, '243da8be-3148-4899-bfb9-c47a50ef1945', peanut_override=True, is_snapped_to_end=True))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_switch_stage_event(
            random_uuid(), start, end, phase_index, is_snapped_to_end=True))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_transform(
            random_uuid(), start, end, phase_index, '77b1f0d5-1bbe-49e1-8e19-3f5e2e5f62de', is_snapped_to_end=True))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_shot(
            random_uuid(), start, end - cool_down, phase_index, '959c765e-cc11-4861-ba1c-ab711f1bffb2', is_snapped_to_end=True, is_logic_enabled=True, j_cut_length=1,
            companion_cam_a='81b6ede6-3f4b-4caf-910b-3dd142f0b98b',
            companion_cam_b='26949517-f0f4-4689-ae37-b94fe68dfee9',
            companion_cam_c='d3e056d9-f660-4ab7-b766-6aaff02b7c78'))
    if cool_down > 0.0:
        tl_obj.add_new_effect_component(
            bg3.game_object_factory.create_tl_shot(
                random_uuid(), end - cool_down, end, phase_index, '3b786a1e-3d4d-4d02-960f-8dd34901f1ec', is_snapped_to_end=True))


#############################################################
# Timeline for '... you all to myself'
#############################################################
lsf = t.unpack('Gustav', 'Public/GustavDev/Timeline/Generated/WYR_DapperDrow_SiblingsThreeWay.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
tl = bg3.bg3_game_object_dialog_timeline(lsx)

ec = tl.get_effect_component('d482b324-2af0-4148-9588-5c0430bce81a')
bg3.set_node_attribute(ec, 'EndTime', 'float', '468.2')

ec = tl.get_effect_component('92581c30-236e-4cf8-94c0-98a20b45607f')
bg3.set_node_attribute(ec, 'StartTime', 'float', '468.2')

ec = tl.get_effect_component('b4bab808-d053-4bfc-8b2e-c77b1c46bdba')
keys_node = ec.find("children/node[@id='Keys']/children")
target_node = None
for key_node in ec.findall("children/node[@id='Keys']/children/node"):
    attributes = bg3.get_node_attributes(key_node)
    if 'Time' in attributes and attributes['Time'] == '469.75613':
        if target_node is not None:
            raise RuntimeError('Incompatible timeline')
        target_node = key_node
if target_node is None:
    raise RuntimeError('Incompatible timeline')
bg3.set_node_attribute(target_node, 'Time', 'float', '468.2')


###########################################################
# Timeline for new dialogs nodes
###########################################################

#
# Just like that...? I thought we had something special. Something lasting.
#
voice_duration = 6.7443 + 0.3
start_time = tl.get_timeline_duration()
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(just_like_that_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.78)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 4.33)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32')
    },
    {
        'Time': ('float', str(start_time + 5.91)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2048')
    },
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, just_like_that_node_uuid, emotion_keys)


#
# Fine. But understand that I'll cut you loose the moment I have to.
#
voice_duration = 3.97
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(cut_you_loose_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time + 0.12)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '8')
    },
    {
        'Time': ('float', str(start_time + 1.5)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 3.26)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    }
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, cut_you_loose_node_uuid, emotion_keys, cool_down=0.0)


#
# At least you're honest. Don't do that again.
#
voice_duration = 3.11
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(dont_do_this_again_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 0.65)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    },
    {
        'Time': ('float', str(start_time + 1.79)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16')
    }
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, dont_do_this_again_node_uuid, emotion_keys)


#
# You're a bad liar. And perhaps an untrustworthy ally.
#
voice_duration = 6.3 + 1.0
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(bad_liar_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time + 0.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '128'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 3.0)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32')
    },
    {
        'Time': ('float', str(start_time + 4.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2048')
    }
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, bad_liar_node_uuid, emotion_keys, cool_down=1.0)


#
# Best if you leave me alone, for now.
#
voice_duration = 3.54
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(best_leave_me_alone_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time + 0.5)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '8')
    },
    {
        'Time': ('float', str(start_time + 2.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '128'),
        'Variation': ('int32', '1')
    }
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, best_leave_me_alone_uuid, emotion_keys, cool_down=0.0)

#
# Now leave me alone.
#
voice_duration = 2.53
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(now_leave_me_alone_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '8')
    },
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, now_leave_me_alone_uuid, emotion_keys, cool_down=0.0)

#
# So... I gather your affections have drifted elsewhere. Curious.
#
voice_duration = 6.31 + 0.3
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(your_affections_drifted_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    },
    {
        'Time': ('float', str(start_time + 3.35)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.18)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    }
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, your_affections_drifted_uuid, emotion_keys)

#
# Oh don't be like that - you've made your bed, now go roll around in it with your new beau.
#
voice_duration = 7
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(your_new_beau_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '128'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.5)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
    },
    {
        'Time': ('float', str(start_time + 4.11)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024')
    },
    {
        'Time': ('float', str(start_time + 6.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    }    
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, your_new_beau_uuid, emotion_keys, cool_down=0.0)

#
# In truth, I don't think I'd want to be your spare lover. I'd always want more of you than you'd have to spare. Better perhaps to bow out with dignity.
#
voice_duration = 13.06 + 0.3
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(spare_lover_uuid, voice_duration, 1)

# effect components

emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    },
    {
        'Time': ('float', str(start_time + 1.82)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
    },
    {
        'Time': ('float', str(start_time + 3.56)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32')
    },
    {
        'Time': ('float', str(start_time + 5.29)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 8.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 11.0)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 11.8)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }    
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, spare_lover_uuid, emotion_keys)

#
# Well that's one way to end things.
#
voice_duration = 5.29 + 0.3
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(way_to_end_things_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time + 0.54)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16')
    },
    {
        'Time': ('float', str(start_time + 2.14)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.35)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 4.01)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '128')
    }

)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, way_to_end_things_uuid, emotion_keys)

#
# We aren't dear friends now, if that's what you're asking.
#
voice_duration = 3.0
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(arent_dear_friends_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time + 0.0)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024')
    },
    {
        'Time': ('float', str(start_time + 1.5)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    }
)
create_effect_components_drow_twins(tl, start_time, end_time, new_phase_index, arent_dear_friends_uuid, emotion_keys, cool_down=0.0)

# Save patched timeline
patched_lsx = tl.save_to(os.path.join(mod_path, 'Public/GustavDev/Timeline/Generated/WYR_DapperDrow_SiblingsThreeWay.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
###########################################
# Shar idol kiss fix
###########################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_BackgroundChapter.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
kiss_start_random_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_Kiss_StartRandom, True, slot_idx_shadowheart),))
shadowheart_random_kiss_start_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_StartRandom, True, slot_idx_shadowheart),))
d.patch_dialog_node_flags('8203a694-02be-4f2a-8059-e9b1cbc55b2f', setflags=[kiss_start_random_true, shadowheart_random_kiss_start_true])


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_BackgroundChapter.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
############################################
# ShadowHeart_InParty2_Nested_Romance.lsf
############################################

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_Romance.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# Set the custom flag that enables replays of the skinny dipping cutscene

slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)

more_opportunities_to_slip_away_true = bg3.create_flag_group('Object', ((ORI_ShadowheartMoreOpportunitiesToSlipAway, True, slot_idx_shadowheart),))

d.patch_dialog_node_flags('08c8b4f5-79df-4b9b-9e11-2e2c0cf06a3d', setflags=[more_opportunities_to_slip_away_true])
d.patch_dialog_node_flags('277288c2-302f-4e53-9e3d-02974e7ac352', setflags=[more_opportunities_to_slip_away_true])

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_Romance.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
####################################################################
# ShadowHeart_InParty2_Nested_DefaultChapter.lsf
####################################################################

####################################################################
# Selune Shadowheart doen't want to share Tav with Halsin: dialog
####################################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_DefaultChapter.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)


# speaker slots
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)
slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)

# flags
shadowheart_enemy_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),))
shadowheart_enemy_of_shar_false = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, False, None),))
shadowheart_chosen_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_SharPath, True, None),))
tav_partnered_false = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, False, slot_idx_tav),))
tav_brokenup_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_WasPartneredWithShadowheart, True, slot_idx_tav),))
halsin_sharing_ok_true = bg3.create_flag_group('Object', ((bg3.FLAG_CAMP_Halsin_CRD_Romance_PartnerAllowsHalsin, True, slot_idx_tav),))
halsin_sharing_not_ok_true = bg3.create_flag_group('Object', ((bg3.FLAG_CAMP_Halsin_CRD_Romance_PartnerDoesNotAllowHalsin, True, slot_idx_tav),))
shadowheart_selune_saved_parents_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_RejectShar_SavedParents, True, None),))
shadowheart_selune_saved_parents_false = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_RejectShar_SavedParents, False, None),))

# dialog uuids
# these will work for Sharran path only
ori_willing_to_share_node_uuid = 'd068cdda-889c-48e4-862b-3f7582a2178a'        # ha4ef192dg5572g46a4g8650g392d3e528c46 "He's open-minded, and willing to share... as long as you are."
ori_space_for_you_and_i_node_uuid = '6c42318e-a9f1-447b-bf53-0395e02ce610'     # hd659b6abge7f2g4246gbdfag871ce01df511 "He wants me. And I want him. I'm not sure if there's space for you and I."
ori_forget_it_wandering_eye_node_uuid = '1a331bb1-d9e2-4ad8-a625-6bc349eb9430' # hdddd3031g1a88g4096g97e7gc4c0527b20c8 "Forget it. Just my wandering eye. I'll tell him I'm not interested."

# replacement nodes for Selune path
new_willing_to_share_node_uuid = 'd8739c08-8abd-4d6c-80d0-af66e42d966f'
new_space_for_you_and_i_node_uuid = 'd7f46d8d-e432-4599-99f2-9ae107b7b90a'
new_forget_it_wandering_eye_node_uuid = '7f98e7dd-5724-4508-a57a-70e7023d74ae'

# reactions to the new nodes
breakup_reaction_node_uuid = '522b8845-5f52-4b19-b4fa-ffe92eeeff5d' # existing node, reposnse to new_space_for_you_and_i_node_uuid
spare_lover_node_uuid = '2c250206-77c2-4feb-a73e-c80a6fe285b4' # response to new_willing_to_share_node_uuid
want_be_with_you_node_uuid = 'cdbf6ef1-f01a-455e-ad95-016ce20741d4'
thank_you_understanding_node_uuid = 'b3558b5e-8e65-467e-ba57-fd72b4050c7d'
almost_flattered_node_uuid = 'fac231c8-8200-445f-9b5f-5f43281017bc'
fleeting_relationship_node_uuid = '7d7e27c7-87c4-4074-b9a7-d8f43b146aa0'
i_suppose_it_was_node_uuid = 'b80794d3-eb9c-4cbd-b593-1efb50153d84'
not_meant_to_be_node_uuid = 'd0bff72f-3e42-4adc-bec2-0ccabe6ac20b'

# unused
matter_closed_then_node_uuid = '7766e3c6-adee-4790-b7b5-86fe143bb13a'

# the parent node for all new nodes
youre_talking_about_halsin_uuid = '3da75e80-d9eb-4ca1-9c0e-6cf8bd0938ac'

d.patch_dialog_node_flags(ori_willing_to_share_node_uuid, checkflags=[shadowheart_chosen_of_shar_true])
d.patch_dialog_node_flags(ori_space_for_you_and_i_node_uuid, checkflags=[shadowheart_chosen_of_shar_true])
d.patch_dialog_node_flags(ori_forget_it_wandering_eye_node_uuid, checkflags=[shadowheart_chosen_of_shar_true])

d.patch_dialog_append_child(youre_talking_about_halsin_uuid, new_willing_to_share_node_uuid)
d.patch_dialog_append_child(youre_talking_about_halsin_uuid, new_space_for_you_and_i_node_uuid)
d.patch_dialog_append_child(youre_talking_about_halsin_uuid, new_forget_it_wandering_eye_node_uuid)

# new dialog nodes

# He wants me. And I want him. I'm not sure if there's space for you and I.
new_space_for_you_and_i_node = bg3.create_standard_dialog_node(
    new_space_for_you_and_i_node_uuid,
    slot_idx_tav,
    [breakup_reaction_node_uuid],
    'hd659b6abge7f2g4246gbdfag871ce01df511',
    '1',
    '45e9d401-b94a-434b-9620-11788ff6e743',
    constructor='TagQuestion',
    setflags=[tav_partnered_false, tav_brokenup_true, halsin_sharing_ok_true],
    checkflags=[shadowheart_enemy_of_shar_true])
d.add_dialog_node(new_space_for_you_and_i_node)

# He's open-minded, and willing to share... as long as you are.
new_willing_to_share_node = bg3.create_standard_dialog_node(
    new_willing_to_share_node_uuid,
    slot_idx_tav,
    [spare_lover_node_uuid],
    'ha4ef192dg5572g46a4g8650g392d3e528c46',
    '1',
    '5af478e7-7282-4ea6-b996-cdfb088ff911',
    constructor='TagQuestion',
    setflags=[],
    checkflags=[shadowheart_enemy_of_shar_true])
d.add_dialog_node(new_willing_to_share_node)

# Forget it. Just my wandering eye. I'll tell him I'm not interested.
new_forget_it_wandering_eye_node = bg3.create_standard_dialog_node(
    new_forget_it_wandering_eye_node_uuid,
    slot_idx_tav,
    [almost_flattered_node_uuid],
    'hdddd3031g1a88g4096g97e7gc4c0527b20c8',
    '1',
    '96c262c1-419a-46d7-bd6d-0c514ae024dc',
    constructor='TagQuestion',
    setflags=[halsin_sharing_not_ok_true],
    checkflags=[shadowheart_enemy_of_shar_true])
d.add_dialog_node(new_forget_it_wandering_eye_node)

# In truth, I don't think I'd want to be your spare lover. I'd always want more of you than you'd have to spare. Better perhaps to bow out with dignity.
spare_lover_node = bg3.create_standard_dialog_node(
    spare_lover_node_uuid,
    slot_idx_shadowheart,
    [fleeting_relationship_node_uuid, want_be_with_you_node_uuid],
    'hd3fd298bgb472g4e8bg8e74gaceeb20de6e1',
    '1',
    '96c262c1-419a-46d7-bd6d-0c514ae024dc',
    constructor='TagAnswer',
    setflags=[halsin_sharing_not_ok_true],
    checkflags=[shadowheart_enemy_of_shar_true])
d.add_dialog_node(spare_lover_node)

# Our relationship was... fleeting. I want to move on.
fleeting_relationship_node = bg3.create_standard_dialog_node(
    fleeting_relationship_node_uuid,
    slot_idx_tav,
    [i_suppose_it_was_node_uuid],
    'hf278c5d2g81beg46abgaa45g649a20dfeb09',
    '1',
    '7a13b403-aab1-4f77-a8c0-9addcded0864',
    constructor='TagQuestion',
    setflags=[tav_partnered_false, tav_brokenup_true, halsin_sharing_ok_true],
    checkflags=[])
d.add_dialog_node(fleeting_relationship_node)

# I suppose it was. And don't worry - I'm not going to toss your belongings into the campfire or anything.
i_suppose_it_was_node = bg3.create_standard_dialog_node(
    i_suppose_it_was_node_uuid,
    slot_idx_shadowheart,
    [not_meant_to_be_node_uuid],
    'h11cbe8fcg20cdg498bgb7cbg47060b5530a6',
    '3',
    '9098026b-dd62-4620-8169-31f922f715ef',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[shadowheart_enemy_of_shar_true])
d.add_dialog_node(i_suppose_it_was_node)

# Maybe you and I are not meant to be, I don't know. I sense I'll have little time for distractions, moving forward. Especially ones that don't bear fruit.
not_meant_to_be_node = bg3.create_standard_dialog_node(
    not_meant_to_be_node_uuid,
    slot_idx_shadowheart,
    [],
    'h03a13c89ge885g4ebcgbc71gb2d502c80f3a',
    '1',
    '6a6069d3-d483-4045-be83-6bb624b9fc01',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[shadowheart_enemy_of_shar_true],
    end_node=True)
d.add_dialog_node(not_meant_to_be_node)
    
# I didn't realize your feel this way. I want to be with you... Forget I ever said anything.
want_be_with_you_node = bg3.create_standard_dialog_node(
    want_be_with_you_node_uuid,
    slot_idx_tav,
    [thank_you_understanding_node_uuid],
    'h9635e41bge285g4f12gb61bg13692d55fba6',
    '1',
    'd1720689-fee3-47eb-b68c-73bb2afa161f',
    constructor='TagQuestion',
    setflags=[],
    checkflags=[])
d.add_dialog_node(want_be_with_you_node)

# Thank you. I had a feeling you'd be understanding.
thank_you_understanding_node = bg3.create_standard_dialog_node(
    thank_you_understanding_node_uuid,
    slot_idx_shadowheart,
    [],
    'hc6d2bb77g1250g40e2gac71g74c4d0c686ff',
    '1',
    '19112db8-2a83-4a83-b0e2-269796d8eeca',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[shadowheart_enemy_of_shar_true],
    end_node=True)
d.add_dialog_node(thank_you_understanding_node)

# I'm almost flattered. Almost.
almost_flattered_node = bg3.create_standard_dialog_node(
    almost_flattered_node_uuid,
    slot_idx_shadowheart,
    [],
    'he817ea29gb437g4509gaa6egf9f4acf255a0',
    '1',
    '6593a0c1-adc1-46a6-a7a3-2eef70aa4b58',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[shadowheart_enemy_of_shar_true],
    end_node=True)
d.add_dialog_node(almost_flattered_node)


# UNUSED
# Thank you. I hope we can consider the matter closed then.
matter_closed_then_node = bg3.create_standard_dialog_node(
    matter_closed_then_node_uuid,
    slot_idx_shadowheart,
    [],
    'h6c228a6fg8251g4ea9gb6dagb6256667ca21',
    '1',
    '3fe4fb07-eeee-4deb-8c54-8454b97c7fdc',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[shadowheart_enemy_of_shar_true],
    end_node=True)
d.add_dialog_node(matter_closed_then_node)

#############################################################################################################
# Shadowheart: new response to "Admit it - you've never had a relationship quite like this one, have you?"
#############################################################################################################

admit_it_node_uuid = '1768e8f4-7100-448d-8422-dd41ded1014d'
even_if_i_could_remember_node_uuid = '067285cc-d3e7-4190-b785-7d4a61bad7d3'
the_way_i_was_raised_node_uuid = '1921ef97-3e74-4194-88a9-94d4b4c10fb1'
a_lots_changed_node_uuid = 'cd6593a9-b021-4721-b370-7f68e934ded4'
i_sougth_to_confide_node_uuid = 'aa276109-e497-4c76-97f7-3b42c43fd47e'

the_way_i_was_raised_node = bg3.create_standard_dialog_node(
    the_way_i_was_raised_node_uuid,
    slot_idx_shadowheart,
    [a_lots_changed_node_uuid],
    'h58d907fbg3657g4f4egbca2g4542dd67e653',
    '3',
    '5b255972-c650-4464-a852-b0be05d4872f',
    constructor='TagAnswer',
    checkflags=[shadowheart_enemy_of_shar_true])
d.add_dialog_node(the_way_i_was_raised_node)

a_lots_changed_node = bg3.create_standard_dialog_node(
    a_lots_changed_node_uuid,
    slot_idx_shadowheart,
    [i_sougth_to_confide_node_uuid],
    'h0d2027f1g386eg45bbg8a6ag7ab77f651a6c',
    '1',
    '6727877f-b790-4b32-9896-53e5dd621b28',
    constructor='TagAnswer')
d.add_dialog_node(a_lots_changed_node)

i_sougth_to_confide_node = bg3.create_standard_dialog_node(
    i_sougth_to_confide_node_uuid,
    slot_idx_shadowheart,
    [],
    'h9b00b4fbgd0e0g4bbcgadc0gdbea99682ab5',
    '1',
    '01a66307-baa7-4665-b8dc-95532dbad006',
    constructor='TagAnswer')
d.add_dialog_node(i_sougth_to_confide_node)

d.patch_dialog_node_flags(even_if_i_could_remember_node_uuid, checkflags=[shadowheart_enemy_of_shar_false])
d.patch_dialog_append_child(admit_it_node_uuid, the_way_i_was_raised_node_uuid, index=0)

#######################################
# Shadowheart: more kisses
#######################################

shadowheart_random_kiss_start_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_StartRandom, True, slot_idx_shadowheart),))

may_i_have_a_kiss_node_uuid = '5752078a-349c-4ba7-b8de-3e9341cb0c9c'

d.patch_dialog_node_flags(may_i_have_a_kiss_node_uuid, setflags=[shadowheart_random_kiss_start_true])

#######################################
# Shadowheart: more swimming lessons
#######################################

# Tav may ask Shadowheart if she needs more swimming lessons after the first one was discussed

shadowheart_romanse_scene_true = bg3.create_flag_group('Object', ((ORI_ShadowheartAnotherSwimmingLesson, True, slot_idx_shadowheart),))
camp_night_true = bg3.create_flag_group('Global', ((bg3.FLAG_GLO_CAMP_State_NightMode, True, None),))

seize_the_opportunity_preconditions = bg3.create_flag_group('Object', (
    (ORI_ShadowheartMoreOpportunitiesToSlipAway, True, slot_idx_shadowheart),
    (ORI_ShadowheartAnotherSwimmingLessonReplied, False, slot_idx_shadowheart),
))

shadowheart_replied_true = bg3.create_flag_group('Object', ((ORI_ShadowheartAnotherSwimmingLessonReplied, True, slot_idx_shadowheart),))
shadowheart_approval_60_true = bg3.create_flag_group('Object', ((bg3.FLAG_Approval_AtLeast_60_For_Sp2, True, slot_idx_shadowheart),))
shadowheart_approval_60_false = bg3.create_flag_group('Object', ((bg3.FLAG_Approval_AtLeast_60_For_Sp2, False, slot_idx_shadowheart),))


another_swim_lesson_node_uuid = 'ff663060-bb62-48d8-928d-5253b65da04b'
took_the_words_node_uuid = 'dca8eede-5035-4977-bca7-cf8a08c1efb4'
its_a_deal_node_uuid = '738a3386-1a00-4324-afe6-95cb236c127a'
not_right_now_node_uuid = '62e11af0-bd3b-4f5a-8851-ca91dae393b4'

# Others seem quite tired, they'll be asleep soon. Don't you think we could seize the opportunity?
another_swim_lesson_node = bg3.create_standard_dialog_node(
    another_swim_lesson_node_uuid,
    slot_idx_tav,
    [took_the_words_node_uuid, not_right_now_node_uuid],
    'h06a5cd66g501bg402bgb1e3g41bd32d9ca18',
    '1',
    'f793f906-dc08-4cac-9ad7-4c97e390e4fc',
    constructor='TagQuestion',
    checkflags=[
        bg3.create_flag_group('Global', (
            (bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),
            (bg3.FLAG_GLO_CAMP_State_NightMode, True, None),
        )),
        bg3.create_flag_group('Object', (
            (bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),
            (ORI_ShadowheartMoreOpportunitiesToSlipAway, True, slot_idx_shadowheart),
            (ORI_ShadowheartAnotherSwimmingLessonReplied, False, slot_idx_shadowheart),
        ))])
d.add_dialog_node(another_swim_lesson_node)

# You took the words right out of my mouth.
took_the_words_node = bg3.create_standard_dialog_node(
    took_the_words_node_uuid,
    slot_idx_shadowheart,
    [its_a_deal_node_uuid],
    'hc89bd245g631dg480ag9218g7d20f8f9422c',
    '1',
    '72bb47ca-818d-49ca-b8c6-aed90ed59a6a',
    constructor='TagAnswer',
    checkflags=[shadowheart_approval_60_true])
d.add_dialog_node(took_the_words_node)

# It's a deal.
its_a_deal_node = bg3.create_standard_dialog_node(
    its_a_deal_node_uuid,
    slot_idx_shadowheart,
    [],
    'hfdb06debg5bd8g49b8g86e1gbe7b75b60100',
    '1',
    '5ca4af10-9855-40f2-8abe-d846c0f4d9b0',
    constructor='TagAnswer',
    setflags=[shadowheart_romanse_scene_true, shadowheart_replied_true],
    end_node=True)
d.add_dialog_node(its_a_deal_node)

# Perhaps... not right now. As tempting as you make it sound.
not_right_now_node = bg3.create_standard_dialog_node(
    not_right_now_node_uuid,
    slot_idx_shadowheart,
    [],
    'h2df9f309g5badg4c17gb9efgff4360cabd70',
    '1',
    '0d7304c8-681a-4b1e-b5e9-5476d52fa095',
    constructor='TagAnswer',
    setflags=[shadowheart_replied_true],
    checkflags=[shadowheart_approval_60_false],
    end_node=True)
d.add_dialog_node(not_right_now_node)
 

d.patch_dialog_append_child('23749c85-4289-4965-a7db-1909f5cb63a2', another_swim_lesson_node_uuid, index=0)

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_DefaultChapter.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
######################################################################
# Timeline: ShadowHeart_InParty2_Nested_DefaultChapter.lsf
######################################################################

def create_effect_components_shadowheart(
    tl_obj: bg3.bg3_game_object_dialog_timeline,
    start: float,
    end: float,
    phase_index: str,
    node_uuid: str,
    camera_idx: int,
    emotions: tuple,
    show_tav: float=0.0,
    switch_camera1: tuple[float, int]=(0.0, 0),
    switch_camera2: tuple[float, int]=(0.0, 0)
) -> None:
    cameras_uuids = [
        '0e8837db-4344-48d0-9175-12262c73806b',
        '7b067edd-f53f-49e1-95bc-0986e6e2ca2f',
        'b4155335-5e08-4d85-8ccd-ddebf5507447',
        'd76eaab3-040b-4871-9c1d-4a8624f37cd2',
        'e08db860-1e62-4271-bf4e-d51602468573',
        'e7f21f15-f386-40f4-bb0f-2f9f42249ad1'
    ]
    camera_uuid = cameras_uuids[camera_idx]
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_voice(
            random_uuid(), start, end, phase_index, node_uuid, 'c15775d6-4f49-53bb-17b7-ee5e158912a8'))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_emotion_event(
            random_uuid(), start, end, phase_index, 'c15775d6-4f49-53bb-17b7-ee5e158912a8', emotions, is_snapped_to_end=True))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_shot(
            random_uuid(), start, end - show_tav, phase_index, camera_uuid))
    if show_tav > 0.0:
        tl_obj.add_new_effect_component(
            bg3.game_object_factory.create_tl_shot(
                random_uuid(), end - show_tav, end, phase_index, cameras_uuids[2]))
    if switch_camera1[0] > 0.0:
        tl_obj.add_new_effect_component(
            bg3.game_object_factory.create_tl_shot(
                random_uuid(), end - switch_camera1[0], end, phase_index, cameras_uuids[switch_camera1[1]]))
    if switch_camera2[0] > 0.0:
        tl_obj.add_new_effect_component(
            bg3.game_object_factory.create_tl_shot(
                random_uuid(), end - switch_camera2[0], end, phase_index, cameras_uuids[switch_camera2[1]]))


lsf = t.unpack('Gustav', 'Public/GustavDev/Timeline/Generated/ShadowHeart_InParty2_Nested_DefaultChapter.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
tl = bg3.bg3_game_object_dialog_timeline(lsx)


############################################################################
# Shadowheart replies to a proposal of sliping away when other are asleep
############################################################################

#
# You took the words right out of my mouth.
#
voice_duration = 2.51 + 0.2
start_time = tl.get_timeline_duration()
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(took_the_words_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.0)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, took_the_words_node_uuid, 1, emotion_keys)


#
# It's a deal.
#
voice_duration = 2.33 + 0.5
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(its_a_deal_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '5')
    },
    {
        'Time': ('float', str(start_time + 1.33)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, its_a_deal_node_uuid, 3, emotion_keys, show_tav=0.5)

#
# Perhaps... not right now. As tempting as you make it sound.
#
voice_duration = 4.383 + 0.5
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(not_right_now_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 0.94)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024')
    },
    {
        'Time': ('float', str(start_time + 2.86)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '2')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, not_right_now_node_uuid, 1, emotion_keys, show_tav=0.5)

#############################################################################################################
# Shadowheart: new response to "Admit it - you've never had a relationship quite like this one, have you?"
#############################################################################################################

#
# The way I was raised, the way I was trained... well, it was positively encouraged, to get to know each other. Even from the memories I can recall, there's stories I could tell you...
#
voice_duration = 15.948
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(the_way_i_was_raised_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.765)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024')
    },
    {
        'Time': ('float', str(start_time + 6.046)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 9.574)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '3')
    },
    {
        'Time': ('float', str(start_time + 13.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '1')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, the_way_i_was_raised_node_uuid, 1, emotion_keys, switch_camera1=(6.0, 0))


#
# A lot's changed since then. More than I ever thought was possible.
#
voice_duration = 4.334
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(a_lots_changed_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16')
    },
    {
        'Time': ('float', str(start_time + 2.14)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.4)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, a_lots_changed_node_uuid, 1, emotion_keys)

#
# It's difficult to put into words... I can't remember the last time I sought to confide in someone like this - maybe I never have, for all I know. But now it just feels... right.
#
voice_duration = 14.938
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(i_sougth_to_confide_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16')
    },
    {
        'Time': ('float', str(start_time + 3.107)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 8.342)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 11.111)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, i_sougth_to_confide_node_uuid, 2, emotion_keys, switch_camera1=(12.4, 1))


######################################################################
# Selune Shadowheart doen't want to share Tav with Halsin: timeline
######################################################################

#
# In truth, I don't think I'd want to be your spare lover. I'd always want more of you than you'd have to spare. Better perhaps to bow out with dignity.
#
voice_duration = 13.06 + 0.3
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(spare_lover_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    },
    {
        'Time': ('float', str(start_time + 1.82)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16'),
    },
    {
        'Time': ('float', str(start_time + 3.56)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32')
    },
    {
        'Time': ('float', str(start_time + 5.29)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 8.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 11.0)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 11.8)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }    
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, spare_lover_node_uuid, 1, emotion_keys, show_tav=0.3)

#
# Thank you. I hope we can consider the matter closed then.
#
voice_duration = 5.0
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(matter_closed_then_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 1.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '1')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, matter_closed_then_node_uuid, 0, emotion_keys)

#
# Thank you. I had a feeling you'd be understanding.
#
voice_duration = 4.53
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(thank_you_understanding_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 2.48)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, thank_you_understanding_node_uuid, 1, emotion_keys)

#
# I'm almost flattered. Almost.
#
voice_duration = 4.45
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(almost_flattered_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time + 0.13)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 1.84)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, almost_flattered_node_uuid, 1, emotion_keys)

#
# I suppose it was. And don't worry - I'm not going to toss your belongings into the campfire or anything.
#
voice_duration = 8.31
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(i_suppose_it_was_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1024'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.98)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64')
    },
    {
        'Time': ('float', str(start_time + 4.73)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '64'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 6.26)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4'),
        'Variation': ('int32', '2')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, i_suppose_it_was_node_uuid, 1, emotion_keys)

#
# Maybe you and I are not meant to be, I don't know. I sense I'll have little time for distractions, moving forward. Especially ones that don't bear fruit.
#
voice_duration = 11.2
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(not_meant_to_be_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32')
    },
    {
        'Time': ('float', str(start_time + 4.76)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16')
    },
    {
        'Time': ('float', str(start_time + 9.05)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2048')
    }
)
create_effect_components_shadowheart(tl, start_time, end_time, new_phase_index, not_meant_to_be_node_uuid, 0, emotion_keys)

# save patched timeline
patched_lsx = tl.save_to(os.path.join(mod_path, 'Public/GustavDev/Timeline/Generated/ShadowHeart_InParty2_Nested_DefaultChapter.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
####################################################
# ShadowHeart_InParty2_Nested_ShadowheartKiss.lsf
####################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_ShadowheartKiss.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# speaker slots
slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)

# flags
shadowheart_kiss_version_a_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_VersionA, True, slot_idx_shadowheart),))
shadowheart_kiss_version_b_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_VersionB, True, slot_idx_shadowheart),))
shadowheart_kiss_version_c_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_VersionC, True, slot_idx_shadowheart),))
shadowheart_kiss_version_d_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_VersionD, True, slot_idx_shadowheart),))
shadowheart_kiss_version_e_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_VersionE, True, slot_idx_shadowheart),))
shadowheart_kiss_version_f_true = bg3.create_flag_group('Object', ((ORI_ShadowheartKiss_VersionF, True, slot_idx_shadowheart),))

# patch kiss nodes
d.patch_dialog_node_flags('5f5e750e-d2e2-4e2e-90fe-e6f7fc8eea71', checkflags=[shadowheart_kiss_version_a_true])
d.patch_dialog_node_flags('835d0310-5eca-d609-2845-b6692e047f80', checkflags=[shadowheart_kiss_version_b_true])
d.patch_dialog_node_flags('bd660b28-e92c-2ea0-2303-dd1fb33a8cc8', checkflags=[shadowheart_kiss_version_c_true])
d.patch_dialog_node_flags('ccddbf44-b77d-ba97-54f4-a3332ca49b4b', checkflags=[shadowheart_kiss_version_d_true])
d.patch_dialog_node_flags('0dffa14a-c979-c806-3edf-6313dab6e589', checkflags=[shadowheart_kiss_version_e_true])
d.patch_dialog_node_flags('e78d9f78-9dee-6a1c-63c6-8b06ec82c2bc', checkflags=[shadowheart_kiss_version_f_true])


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_ShadowheartKiss.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
#################################################
# CAMP_Shadowheart_SkinnyDipping_SD_ROM.lsf
#################################################

#################################################
# Modifications to the skinny dipping cutscene
#################################################

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Camp/SoloDreams/CAMP_Shadowheart_SkinnyDipping_SD_ROM.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)

# Flags
kiss_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_Kiss_StartRandom, True, slot_idx_shadowheart),))
more_opportunities_to_slip_away_true = bg3.create_flag_group('Object', ((ORI_ShadowheartMoreOpportunitiesToSlipAway, True, slot_idx_shadowheart),))
more_opportunities_to_slip_away_false = bg3.create_flag_group('Object', ((ORI_ShadowheartMoreOpportunitiesToSlipAway, False, slot_idx_shadowheart),))

# Supperss nodes for the 2nd run of the unsafe cutscene as they don't make sense anymore
d.patch_dialog_node_flags('a36d3365-38ba-8a0a-e249-8491cf394f2c', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('0403b053-4b6c-9cfb-7b95-007c6024509b', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('955c8afa-d714-09e6-2541-a409d7919304', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('bbd5a13c-fa69-58c4-e0d8-1b65c3dc908d', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('d2205284-8cbe-0cba-be5a-6693eb699a5a', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('c0230403-b3a9-2203-baff-7102710154c7', checkflags=[more_opportunities_to_slip_away_false])

# Supperss nodes for the 2nd run of the safe cutscene as they don't make sense anymore
d.patch_dialog_node_flags('c70dbc9c-5afe-909b-7514-6480a9c2c79c', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('a00730b5-70c7-13ab-9263-239d28168c29', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('d53947d8-21fc-df12-a0f0-c43c4d080911', checkflags=[more_opportunities_to_slip_away_false])
d.patch_dialog_node_flags('5e5a9953-4814-8853-b8ee-833e25b05af8', checkflags=[more_opportunities_to_slip_away_false])


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Camp/SoloDreams/CAMP_Shadowheart_SkinnyDipping_SD_ROM.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
########################################################
# Timeline: CAMP_Shadowheart_SkinnyDipping_SD_ROM.lsf
########################################################

lsf = t.unpack('Gustav', 'Public/GustavDev/Timeline/Generated/CAMP_Shadowheart_SkinnyDipping_SD_ROM.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
tl = bg3.bg3_game_object_dialog_timeline(lsx)


# Delay camera transform when they are kissing on the shore
effect_component = tl.find_effect_component('98020265-3ead-4cc4-9c99-3ff011567e38')
transform_channels = effect_component.find("children/node[@id='TransformChannels']")
transform_channels.remove(transform_channels.find("children"))
transform_channels.append(bg3.et.fromstring("""
    <children>
        <node id="TransformChannel">
            <children>
                <node id="Keys">
                    <children>
                        <node id="Key">
                            <attribute id="Time" type="float" value="350.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="float" value="-0.9371941" />
                        </node>
                        <node id="Key">
                            <attribute id="Time" type="float" value="354.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="float" value="-0.9421899" />
                        </node>
                    </children>
                </node>
            </children>
        </node>
        <node id="TransformChannel">
            <children>
                <node id="Keys">
                    <children>
                        <node id="Key">
                            <attribute id="Time" type="float" value="350.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="float" value="0.2273747" />
                        </node>
                        <node id="Key">
                            <attribute id="Time" type="float" value="354.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="float" value="0.2277535" />
                        </node>
                    </children>
                </node>
            </children>
        </node>
        <node id="TransformChannel">
            <children>
                <node id="Keys">
                    <children>
                        <node id="Key">
                            <attribute id="Time" type="float" value="350.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="float" value="-6.752407" />
                        </node>
                        <node id="Key">
                            <attribute id="Time" type="float" value="354.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="float" value="-6.757811" />
                        </node>
                    </children>
                </node>
            </children>
        </node>
        <node id="TransformChannel">
            <children>
                <node id="Keys">
                    <children>
                        <node id="Key">
                            <attribute id="Time" type="float" value="350.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="fvec4" value="0.013664621 0.3343945 -0.00484906 0.94232166" />
                        </node>
                        <node id="Key">
                            <attribute id="Time" type="float" value="354.75998" />
                            <attribute id="InterpolationType" type="uint8" value="5" />
                            <attribute id="Value" type="fvec4" value="0.22784422 -0.33852422 -0.084851965 -0.90900415" />
                        </node>
                    </children>
                </node>
            </children>
        </node>
        <node id="TransformChannel" />
        <node id="TransformChannel" />
    </children>"""))

# save patched timeline
patched_lsx = tl.save_to(os.path.join(mod_path, 'Public/GustavDev/Timeline/Generated/CAMP_Shadowheart_SkinnyDipping_SD_ROM.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
##############################################################
# PB_Halsin_Shadowheart_ROM_Act3_Selune.lsf
##############################################################

##############################################################
# Shadowheart & Halsin baner, changed Shadowheart's line
##############################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/Party_Banter/PB_Halsin_Shadowheart_ROM_Act3_Selune.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

d.patch_dialog_tagged_text('c271277b-9408-4c66-bf2f-c5b76fac64f4', "hbf7a4276g3c6bg49c0gab09g790c7dcb6428", "2")

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/Party_Banter/PB_Halsin_Shadowheart_ROM_Act3_Selune.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
####################################################################
# Halsin_InParty_Nested_Polyamory.lsf
####################################################################

####################################################################
# Halsin dialog: break up with Selune Shadowheart
####################################################################

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/Halsin_InParty_Nested_Polyamory.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# speaker slots
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)
slot_idx_halsin = d.get_speaker_slot_index(bg3.GBTP_HALSIN)

shadowheart_breakup_start_true = bg3.create_flag_group('Object', ((Shadowheart_BreakUp_Notification_Start, True, slot_idx_tav),))
shadowheart_chosen_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_SharPath, True, None),))
shadowheart_enemy_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),))
tav_partnered_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),))
tav_partnered_false = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, False, slot_idx_tav),))

existing_making_my_own_node_uuid = 'b73b4b91-7c1f-4b0a-975d-68a4e2ee3017'
existing_answer_node_uuid = 'e86250d2-036a-4a13-9d4b-dae85d7193e6'
new_selune_path_node_uuid = '389d34ce-0297-4f86-b6b5-12a2811e0f06'
new_shar_path_node_uuid = 'bd6ee90c-8e29-48e4-a9a9-a045f6ea97e8'
new_not_partnered_node_uuid = '5b616a0c-bedb-4b04-b858-5345c2438dee'

new_selune_path_node = bg3.create_standard_dialog_node(
    new_selune_path_node_uuid,
    slot_idx_halsin,
    [existing_answer_node_uuid],
    '', '', '',
    constructor='TagAnswer',
    setflags=[tav_partnered_false, tav_brokenup_true, shadowheart_breakup_start_true],
    checkflags=[shadowheart_enemy_of_shar_true, tav_partnered_true])
d.add_dialog_node(new_selune_path_node)

new_shar_path_node = bg3.create_standard_dialog_node(
    new_shar_path_node_uuid,
    slot_idx_halsin,
    [existing_answer_node_uuid],
    '', '', '',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[shadowheart_chosen_of_shar_true, tav_partnered_true])
d.add_dialog_node(new_shar_path_node)

new_not_partnered_node = bg3.create_standard_dialog_node(
    new_not_partnered_node_uuid,
    slot_idx_halsin,
    [existing_answer_node_uuid],
    '', '', '',
    constructor='TagAnswer',
    setflags=[],
    checkflags=[tav_partnered_false])
d.add_dialog_node(new_not_partnered_node)

d.patch_dialog_remove_child(existing_making_my_own_node_uuid, existing_answer_node_uuid)
d.patch_dialog_append_child(existing_making_my_own_node_uuid, new_selune_path_node_uuid)
d.patch_dialog_append_child(existing_making_my_own_node_uuid, new_shar_path_node_uuid)
d.patch_dialog_append_child(existing_making_my_own_node_uuid, new_not_partnered_node_uuid)

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/Halsin_InParty_Nested_Polyamory.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
####################################################################
# ShadowHeart_InParty2.lsf
####################################################################

####################################################################
# Shadowheart break up line
####################################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# When Shadowheart breaks up with Tav/Durge because of Mizora, Halsin, or drow twins,
# there is no specific line for any of those; this is a replacvement that works for all non-origin break-ups.

greeting_node_uuid = '8e227955-8a68-42da-98b6-3fcff2c2af5f'
new_answer_node_uuid = '5f23932d-fe2c-4ea6-8a84-8483f63259dc'
dialog_continuation_node_uuid = '0251a191-20a0-4ca5-b8c1-d4c1dd386190'

slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)

shadowheart_break_up_finish_true = bg3.create_flag_group('Object', ((Shadowheart_BreakUp_Notification_Finish, True, slot_idx_tav),))
shadowheart_skinnydipping_false = bg3.create_flag_group('Global', ((bg3.FLAG_NIGHT_Shadowheart_Skinnydipping, False, None),))
tav_partnered_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),))
tav_partnered_false = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, False, slot_idx_tav),))
tav_brokenup_false = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_WasPartneredWithShadowheart, False, slot_idx_tav),))
shadowheart_hugs_are_enabled_true = bg3.create_flag_group('Object', ((ORI_Shadowheart_State_HugsEnabled, True, slot_idx_shadowheart),))
tav_approval_60_true = bg3.create_flag_group('Object', ((bg3.FLAG_Approval_AtLeast_60_For_Sp2, True, slot_idx_shadowheart),))
tav_approval_30_true = bg3.create_flag_group('Object', ((bg3.FLAG_Approval_AtLeast_30_For_Sp2, True, slot_idx_shadowheart),))
tav_approval_10_true = bg3.create_flag_group('Object', ((bg3.FLAG_Approval_AtLeast_10_For_Sp2, True, slot_idx_shadowheart),))
shadowheart_in_camp_true = bg3.create_flag_group('Object', ((bg3.FLAG_CAMP_GLO_State_InCamp, True, slot_idx_shadowheart),))
shadowheart_enemy_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),))

d.patch_dialog_append_child(greeting_node_uuid, new_answer_node_uuid)

# Maybe you and I are not meant to be, I don't know. I sense I'll have little time for distractions, moving forward. Especially ones that don't bear fruit.
new_answer_node = bg3.create_standard_dialog_node(
    new_answer_node_uuid,
    slot_idx_shadowheart,
    [dialog_continuation_node_uuid],
    'h03a13c89ge885g4ebcgbc71gb2d502c80f3a',
    '1',
    '6fe541cb-042e-4620-83b5-49ccdc76700b',
    constructor='TagAnswer',
    setflags=[shadowheart_break_up_finish_true, shadowheart_skinnydipping_false],
    checkflags=[shadowheart_enemy_of_shar_true, tav_partnered_false])
d.add_dialog_node(new_answer_node)

#####################################################################################################
# Bugfix: after saving parents when on enemy of shar path, the discussion about memories was under
#         Shadowheart_InParty_Event_SavedParentsMemoriesEnemy flag, which is the Shar path flag.
#         Obviously, the conversation never pops up. Also, this makes this convo a recurring one
#####################################################################################################

memories_discussion_selune_parents_saved_node_uuid = 'db424664-9086-bb2a-2f73-62b9ab38c641'
memories_discussion_selune_parents_killed_node_uuid = 'ac4359eb-ae3a-87c3-4405-2c0ee04bd934'
memories_discussion_shar_parents_saved_node_uuid = '287b8eb3-4501-97af-f5a8-4fb7c9928257'

# Selund path, saved parents
d.patch_dialog_node_flags(
    memories_discussion_selune_parents_saved_node_uuid,
    setflags=[bg3.create_flag_group('Object', (('2eb239a8-f3f6-474f-a2a7-636ff19407f0', True, slot_idx_tav),))],
    checkflags=[bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_RejectShar_SavedParents, True, None),))])

# Selune path, killed parents
d.patch_dialog_node_flags(
    memories_discussion_selune_parents_killed_node_uuid,
    setflags=[bg3.create_flag_group('Object', (('2825740b-0dc2-4e82-8ce4-ef6b87ea810b', True, slot_idx_tav),))],
    checkflags=[bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_RejectShar_KilledParents, True, None),))])

# Shar path, saved parents
d.patch_dialog_node_flags(
    memories_discussion_shar_parents_saved_node_uuid,
    setflags=[bg3.create_flag_group('Object', (('ad4382a9-a10c-4c2f-981c-6da40ac4682b', True, slot_idx_tav),))],
    checkflags=[bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_Shar_SavedParents, True, None),))])

#
# Give me a night, to try and get my head together.
#

shadowheart_after_parents_true = bg3.create_flag_group('Object', ((ORI_Shadowheart_AfterParents, True, slot_idx_shadowheart),))
give_me_a_night_node_uuid = 'bcfdf718-6d56-45fa-ab0a-967b0f11abfa'

give_me_a_night_node = bg3.create_standard_dialog_node(
    give_me_a_night_node_uuid,
    slot_idx_shadowheart,
    [],
    'h11c7cf31ga874g4f1bgb4e6gf6d126ea12da',
    '2',
    '4616324a-352d-400a-aeb1-d97a3cec8725',
    constructor='TagGreeting',
    checkflags=[shadowheart_after_parents_true],
    end_node=True)
d.add_dialog_node(give_me_a_night_node)

d.add_root_node(give_me_a_night_node_uuid, index=0)

###############################
# IMPOSSIBLE is now POSSIBLE
###############################

# New responses when Tav asks Shadowheart to stay in camp
# Partnered
stay_in_camp_partnered_node_uuid = '851bc647-7551-8a23-6857-d927161bdda8'
stay_in_camp_good_approval_node_uuid = 'd4a79c8b-cf2b-43e6-45f3-cbb1668f73a7'
camp_stay_in_camp_partnered_node_uuid = '276891a3-b88e-8e58-9c9d-07576b9f1144'
camp_stay_in_camp_good_approval_node_uuid = 'e4d71a2f-42e1-664e-9674-97f1c41bb939'
camp_stay_in_camp_medium_approval_node_uuid = '5db50db9-bcba-a51e-dc92-707e4c7e4c0d'

d.patch_dialog_node_flags(stay_in_camp_partnered_node_uuid, checkflags=[tav_partnered_true])
d.patch_dialog_set_tagged_texts(stay_in_camp_partnered_node_uuid, (
    ('h51a40328g2703g40deg839dg5407eac510b0', '1', '4dbee755-ebb9-46d6-a4ea-ce37d231858b', False), # As you like. You behave yourself out there, and come back to me in one piece.
    ('h8d43132dg40a0g4559g9c29gbba086144499', '1', '97eba145-d2d2-4061-825d-8abfd720dcb6', True),  # Very well. Take care of yourself out there. I'll be waiting for you.
    ('h495d4f38g255cg4cd1g8782g8e30ba5e9519', '1', '97bd954b-1f6c-470b-9a68-fc04d230c8f5', True)   # I suppose a some idle time at camp might do me good - as long as I still see you, come nightfall. Take care.
))

d.patch_dialog_node_flags(stay_in_camp_good_approval_node_uuid, checkflags=[tav_approval_30_true])
d.patch_dialog_set_tagged_texts(stay_in_camp_good_approval_node_uuid, (
    ('hf46326deg39d6g4393ga9bcgb25e9e1bff5d', '1', '1f21987f-9aab-4526-9c09-4dee89645619', False), # Well you know best. I'll be ready whenever you need me. Take care of yourself out there.
    ('h9e810175g8c6dg42d8g8f1ag7e009c9be64e', '1', '58d22e78-7413-48a2-be87-3d1591352c80', True),  # I suppose a little 'me time' at camp wouldn't go amiss. Fetch me whenever you need me - and mind yourself out there.
    ('hf7cd7289gf93cg43c7ga6a3g63bd6a73e113', '1', '547fabd2-05ae-43ee-87be-a7cfc9482956', True)   # I'll see you at camp then. Be safe - I'm not sure how we'd manage without you.
))

d.patch_dialog_node_flags(camp_stay_in_camp_partnered_node_uuid, checkflags=[shadowheart_in_camp_true, tav_partnered_true])
d.patch_dialog_set_tagged_texts(camp_stay_in_camp_partnered_node_uuid, (
    ('h8c848104gfacfg4d98g89d0g652051515e5c', '1', 'fa3da9b3-0630-408f-999c-54a193250090', False), # You mind yourself out there, understand? I'll be here when you need me.
    ('h430dac13g0c56g40f3g9829gf764f5d78c38', '1', 'fcfbafb9-a40d-4ba9-89b6-90ae9eec133e', True),  # All right. Be good out there - and if you can't be good, well... don't get caught. I'll be here whenever you need me.
    ('had39a9bcg27b1g4c9cga3e3g56fa8685dd3b', '1', '662097d3-3919-48c6-a03d-3aa448074490', True)   # Take care. I'll keep an eye on this place.
))

d.patch_dialog_node_flags(camp_stay_in_camp_good_approval_node_uuid, checkflags=[shadowheart_in_camp_true, tav_approval_30_true])
d.patch_dialog_set_tagged_texts(camp_stay_in_camp_good_approval_node_uuid, (
    ('had8ee213gca70g4080ga1a2g43a4fe660ea1', '1', '6dcdd429-c1ed-4a8f-8423-6d53f134f6e4', False), # Very well. I do like it here, truth be told; my own little corner, time to think... but I'll be ready when you need me. Take care.
    ('h28d71a83g6dfag47f3gadfbg7828bd366d12', '1', 'c59d0d40-97ff-477f-b2da-43c6a50a2a3a', True),  # Of course, I'll see you in the evenings. Stay safe out there.
    ('h1d4c894fg9a2ag4217g9fbcgabb25c93bfdc', '1', '3d1dcd64-47e5-4695-a3ee-d6aba53696fe', True)   # Take care - I'll be here when you need me.
))
d.patch_dialog_node_flags(camp_stay_in_camp_medium_approval_node_uuid, checkflags=[shadowheart_in_camp_true, tav_approval_10_true])

# Unblock |Hug her|

greeting_node_uuid = '5f864b1a-65af-45de-ac29-d27242ab07b7'
hug_her_node_uuid = 'f5a1f59f-7c05-55d4-3951-849dbdb62b2f'

flag_group = bg3.create_flag_group('Object', (
    (bg3.FLAG_ORI_State_WasPartneredWithShadowheart, False, slot_idx_tav),
    (bg3.FLAG_Approval_AtLeast_60_For_Sp2, True, slot_idx_shadowheart),
    (ORI_Shadowheart_State_HugsEnabled, True, slot_idx_shadowheart),
))

TAG_SHORT = '50e7beca-4e90-43cd-b7c5-c235e236077f'
TAG_DWARF = '486a2562-31ae-437b-bf63-30393e18cbdd'
TAG_DRAGONBORN = '02e5e9ed-b6b2-4524-99cd-cb2bc84c754a'

racist_tag_group = bg3.create_flag_group('Tag', (
    (bg3.TAG_SHORT, False, slot_idx_tav),
    (bg3.TAG_DWARF, False, slot_idx_tav),
    (bg3.TAG_DRAGONBORN, False, slot_idx_tav),
))


d.patch_dialog_node_flags(hug_her_node_uuid, [flag_group, racist_tag_group])
d.patch_dialog_tagged_text(hug_her_node_uuid, 'h4e908b98g9055g4a21gb8b3g118fa3b5250c', '2')

# Move |Hug her| to the top
d.patch_dialog_remove_child(greeting_node_uuid, hug_her_node_uuid)
d.patch_dialog_append_child(greeting_node_uuid, hug_her_node_uuid, index=0)

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
######################################################################
# Shadowheart dialog: ShadowHeart_InParty2.lsf, timeline
######################################################################

def create_effect_components_shadowheart_in_party2(
    tl_obj: bg3.bg3_game_object_dialog_timeline,
    start: float,
    end: float,
    phase_index: str,
    node_uuid: str,
    camera_idx: int,
    emotions: tuple,
    reference_id: Optional[str]=None,
    show_tav: float=0.0
) -> None:
    cameras_uuids = [
        '0e8837db-4344-48d0-9175-12262c73806b',
        '2b1dd4ed-5f01-46a2-a244-ac074d0feff0',
        '8942c483-83c9-4974-9f47-87cd1dd10828',
        '95a53513-08ce-4d80-ae74-e306b51db565',
        'b188e5c9-4ec1-456f-8408-b4a5da405cc5',
        'cde43894-62c3-4f23-8ea7-b772f9357697',
        'd76eaab3-040b-4871-9c1d-4a8624f37cd2',
        'fd96b957-6a74-4f97-a035-eb9641c48242'
    ]
    camera_uuid = cameras_uuids[camera_idx]
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_voice(
            random_uuid(), start, end, phase_index, node_uuid, 'c15775d6-4f49-53bb-17b7-ee5e158912a8', reference_id=reference_id))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_emotion_event(
            random_uuid(), start, end, phase_index, 'c15775d6-4f49-53bb-17b7-ee5e158912a8', emotions, is_snapped_to_end=True))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_shot(
            random_uuid(), start, end - show_tav, phase_index, camera_uuid))
    tl_obj.add_new_effect_component(
        bg3.game_object_factory.create_tl_shot(
            random_uuid(), end - show_tav, end, phase_index, cameras_uuids[2]))

lsf = t.unpack('Gustav', 'Public/GustavDev/Timeline/Generated/ShadowHeart_InParty2.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
tl = bg3.bg3_game_object_dialog_timeline(lsx)


#
# Maybe you and I are not meant to be, I don't know. I sense I'll have little time for distractions, moving forward. Especially ones that don't bear fruit.
#
voice_duration = 11.2
start_time = tl.get_timeline_duration()
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(new_answer_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32')
    },
    {
        'Time': ('float', str(start_time + 4.76)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '16')
    },
    {
        'Time': ('float', str(start_time + 9.05)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2048')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, new_answer_node_uuid, 0, emotion_keys)

#
# Give me a night, to try and get my head together.
#
voice_duration = 3.46753
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(give_me_a_night_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '32'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.06)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2048'),
        'Variation': ('int32', '1')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, give_me_a_night_node_uuid, 0, emotion_keys)


#
# As you like. You behave yourself out there, and come back to me in one piece.
#
voice_duration = 6.0
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(stay_in_camp_partnered_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.8)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.7)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, stay_in_camp_partnered_node_uuid, 0, emotion_keys)


#
# Very well. Take care of yourself out there. I'll be waiting for you.
#
voice_duration = 6.5
start_time = end_time
end_time = start_time + voice_duration
reference_id = '97eba145-d2d2-4061-825d-8abfd720dcb6'

# new phase
new_phase_index = tl.add_new_phase(stay_in_camp_partnered_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.8)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.7)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, stay_in_camp_partnered_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# I suppose a some idle time at camp might do me good - as long as I still see you, come nightfall. Take care.
#
voice_duration = 11.2
start_time = end_time
end_time = start_time + voice_duration
reference_id = '97bd954b-1f6c-470b-9a68-fc04d230c8f5'

# new phase
new_phase_index = tl.add_new_phase(stay_in_camp_partnered_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 3.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 5.7)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 8.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 10.1)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, stay_in_camp_partnered_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# Well you know best. I'll be ready whenever you need me. Take care of yourself out there.
#
voice_duration = 8.1
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(stay_in_camp_good_approval_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 3.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 6.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 7.4)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, stay_in_camp_good_approval_node_uuid, 0, emotion_keys)


#
# I suppose a little 'me time' at camp wouldn't go amiss. Fetch me whenever you need me - and mind yourself out there.
#
voice_duration = 9.0
start_time = end_time
end_time = start_time + voice_duration
reference_id = '58d22e78-7413-48a2-be87-3d1591352c80'

# new phase
new_phase_index = tl.add_new_phase(stay_in_camp_good_approval_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.5)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 6.8)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 7.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, stay_in_camp_good_approval_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# I'll see you at camp then. Be safe - I'm not sure how we'd manage without you.
#
voice_duration = 7.3
start_time = end_time
end_time = start_time + voice_duration
reference_id = '547fabd2-05ae-43ee-87be-a7cfc9482956'

# new phase
new_phase_index = tl.add_new_phase(stay_in_camp_good_approval_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 3.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.5)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 6.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '4')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, stay_in_camp_good_approval_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# You mind yourself out there, understand? I'll be here when you need me.
#
voice_duration = 5.3
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_partnered_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_partnered_node_uuid, 0, emotion_keys)


#
# All right. Be good out there - and if you can't be good, well... don't get caught. I'll be here whenever you need me.
#
voice_duration = 12.1
start_time = end_time
end_time = start_time + voice_duration
reference_id = 'fcfbafb9-a40d-4ba9-89b6-90ae9eec133e'

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_partnered_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 3.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.7)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 8.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 10.1)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_partnered_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# Take care. I'll keep an eye on this place.
#
voice_duration = 3.7
start_time = end_time
end_time = start_time + voice_duration
reference_id = '662097d3-3919-48c6-a03d-3aa448074490'

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_partnered_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_partnered_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# Very well. I do like it here, truth be told; my own little corner, time to think... but I'll be ready when you need me. Take care.
#
voice_duration = 15.1
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_good_approval_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 7.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 10.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 12.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_good_approval_node_uuid, 0, emotion_keys)


#
# Of course, I'll see you in the evenings. Stay safe out there.
#
voice_duration = 7.4
start_time = end_time
end_time = start_time + voice_duration
reference_id = 'c59d0d40-97ff-477f-b2da-43c6a50a2a3a'

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_good_approval_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '3')
    },
    {
        'Time': ('float', str(start_time + 2.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 4.1)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 6.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_good_approval_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# Take care - I'll be here when you need me.
#
voice_duration = 3.9
start_time = end_time
end_time = start_time + voice_duration
reference_id = '3d1dcd64-47e5-4695-a3ee-d6aba53696fe'

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_good_approval_node_uuid, voice_duration, 1, reference_id=reference_id)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 1.3)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.9)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 3.6)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '2')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_good_approval_node_uuid, 0, emotion_keys, reference_id=reference_id)


#
# Very well, don't have too much fun without me. I'll keep watch here in the meantime.
#
voice_duration = 8.1
start_time = end_time
end_time = start_time + voice_duration

# new phase
new_phase_index = tl.add_new_phase(camp_stay_in_camp_medium_approval_node_uuid, voice_duration, 1)

# effect components
emotion_keys = (
    {
        'Time': ('float', str(start_time)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 2.7)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '1')
    },
    {
        'Time': ('float', str(start_time + 5.2)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1'),
        'Variation': ('int32', '2')
    },
    {
        'Time': ('float', str(start_time + 7.1)),
        'InterpolationType': ('uint8', '3'),
        'Emotion': ('int32', '1')
    }
)
create_effect_components_shadowheart_in_party2(tl, start_time, end_time, new_phase_index, camp_stay_in_camp_medium_approval_node_uuid, 0, emotion_keys)


# save patched timeline
patched_lsx = tl.save_to(os.path.join(mod_path, 'Public/GustavDev/Timeline/Generated/ShadowHeart_InParty2.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
################################################
# ShadowHeart_InParty2_Nested_CityChapter.lsf
################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_CityChapter.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)
slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)

tav_partnered_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),))

#######################################################################################
# After the events in the Chamber of Loss, Shadowheart stays in camp until long rest
#######################################################################################

# Enemy of Shar path, killed parents
d.patch_dialog_node_flags(
    'daa105c0-10cc-4334-a550-9a0103674cc4',
    setflags=[bg3.create_flag_group('Object', (
        (ORI_Shadowheart_AfterParents, True, slot_idx_shadowheart),
        (bg3.FLAG_OriginRemoveFromPartyAfterDialog, True, slot_idx_shadowheart),
        ('d59fe46f-cce5-4a2c-ac44-65cfda9073f2', False, slot_idx_tav)
    ))])

# Enemy of Shar path, saved parents
d.patch_dialog_node_flags(
    '48f77fda-8492-4b65-8a7f-a533388250f6',
    setflags=[bg3.create_flag_group('Object', (
        (ORI_Shadowheart_AfterParents, True, slot_idx_shadowheart),
        (bg3.FLAG_OriginRemoveFromPartyAfterDialog, True, slot_idx_shadowheart),
        ('e3c97bf9-c58c-4dfb-ba8e-27cba587d77d', False, slot_idx_tav)
    ))])

# Shar path, saved parents
d.patch_dialog_node_flags(
    'a11549ed-8ffe-417d-a0f4-1ebbe313661d',
    setflags=[bg3.create_flag_group('Object', (
        (ORI_Shadowheart_AfterParents, True, slot_idx_shadowheart),
        (bg3.FLAG_OriginRemoveFromPartyAfterDialog, True, slot_idx_shadowheart),
        ('1e379d40-cd40-4b49-a45f-d9b28c2d0437', False, slot_idx_tav)
    ))])

# What about us - do you still remember all we've been through?
# Show this line only when Tav is partnered with Shadowheart
d.patch_dialog_node_flags('e8e237c0-3953-4791-8980-e1abc1a3fcdb', checkflags=[tav_partnered_true])

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, 'Mods/GustavDev/Story/DialogsBinary/Companions/ShadowHeart_InParty2_Nested_CityChapter.lsf.lsx'))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
#######################################################################
# CAMP_Mizora.lsf
#######################################################################

#######################################################################
# Selune Shadowheart breaks up with Tav if he accepts Mizora's offer
#######################################################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Camp/CAMP_Mizora.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)
slot_idx_mizora = d.get_speaker_slot_index(bg3.GBTP_MIZORA)

tav_smiles_to_mizora_node_uuid = '94e48875-5c35-cd9e-0baa-ea0139142afb'
mizora_tonight_then_node_uuid = 'cf68f2d7-d79d-fdeb-323d-1c35abd9eb10'

selune_path_flags_node_uuid = '00079597-8a47-484c-900c-f77ad1d3e7b5'


shadowheart_enemy_of_shar_true = bg3.create_flag_group('Global', ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),))
tav_partnered_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, True, slot_idx_tav),))
tav_partnered_false = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_PartneredWithShadowheart, False, slot_idx_tav),))
tav_brokenup_true = bg3.create_flag_group('Object', ((bg3.FLAG_ORI_State_WasPartneredWithShadowheart, True, slot_idx_tav),))
shadowheart_breakup_start_true = bg3.create_flag_group('Object', ((Shadowheart_BreakUp_Notification_Start, True, slot_idx_tav),))
shadowheart_skinnydipping_false = bg3.create_flag_group('Global', ((bg3.FLAG_NIGHT_Shadowheart_Skinnydipping, False, None),))

selune_path_flags_node = bg3.create_standard_dialog_node(
    selune_path_flags_node_uuid,
    slot_idx_mizora,
    [mizora_tonight_then_node_uuid],
    '', '', '',
    constructor='TagAnswer',
    setflags=[tav_partnered_false, tav_brokenup_true, shadowheart_skinnydipping_false, shadowheart_breakup_start_true],
    checkflags=[shadowheart_enemy_of_shar_true, tav_partnered_true])
d.add_dialog_node(selune_path_flags_node)

d.patch_dialog_append_child(tav_smiles_to_mizora_node_uuid, selune_path_flags_node_uuid, index=0)

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, "Mods/GustavDev/Story/DialogsBinary/Camp/CAMP_Mizora.lsf.lsx"))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
######################################################
# LOW_SharGrotto_ParentsFate_OM_Shadowheart_COM.lsf
######################################################

######################################################
# Selunite Shadowheart saves parents
######################################################

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/Origin_Moments/LOW_SharGrotto_ParentsFate_OM_Shadowheart_COM.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)

# Shadowheart saves parents
patch = [bg3.et.fromstring(
    '<node id="checkflags"><children><node id="flaggroup" key="type"><attribute id="type" type="FixedString" value="Global" /><children><node id="flag" key="UUID">' +
    '<attribute id="UUID" type="FixedString" value="' + bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath + '" />' +
    '<attribute id="value" type="bool" value="True" />' +
    '</node></children></node></children></node>'    
)]
patch = (bg3.create_xml_node_with_children('checkflags', (
    bg3.create_flag_group("Global", ((bg3.FLAG_ORI_Shadowheart_State_EnemyOfSharPath, True, None),)),
)),)
d.patch_dialog_node('317a6bfd-3788-7ffd-36bb-671d1ad27a14', patch)

patch = (bg3.create_xml_node_with_children('children', (
    bg3.et.fromstring('<node id="child"><attribute id="UUID" type="FixedString" value="317a6bfd-3788-7ffd-36bb-671d1ad27a14" /></node>'),
    bg3.et.fromstring('<node id="child"><attribute id="UUID" type="FixedString" value="9db4f40e-948b-127c-ff26-73fd8c130db4" /></node>'),
)),)
# 1f8d3b87-6a24-cc6c-11c3-684cf1bcdfef
d.patch_dialog_node('6d67773e-2681-77f0-9dcd-0f206794e6ff', patch)
d.patch_dialog_node('c3a6e897-7565-25d4-ef70-24a968e9785b', patch)

tag_god_selune_true = bg3.create_flag_group("Tag", ((bg3.GOD_Selune, True, slot_idx_tav),))
tag_god_selune_false = bg3.create_flag_group("Tag", ((bg3.GOD_Selune, False, slot_idx_tav),))


# DC 20 Charisma/Persuasion check to kill parents
roll_success = "45763e25-35a5-4828-b074-950eb9216175"
roll_failure = "35969b67-647c-4524-b084-2fb2d2c74cf1"
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_success, True, "13a9c749-b989-b71d-760c-c2a55796e202"))
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_failure, False, "317a6bfd-3788-7ffd-36bb-671d1ad27a14"))
dice_roll = bg3.create_dice_roll_dialog_node(
    "502739a5-ba58-d164-f793-d18c14dd8bf6",
    slot_idx_tav, # Tav is in the slot 2
    "Charisma",
    "Persuasion",
    bg3.DC_Act3_Hard,
    roll_success,
    roll_failure,
    "hf7ab97f1g9c21g467bg9feag961801ba37b9",
    "2",
    "8ee03aed-b3b3-490b-a2e6-24fec650c178"
)
d.delete_dialog_node("502739a5-ba58-d164-f793-d18c14dd8bf6")
d.add_dialog_node(dice_roll)

# DC 20 Wisdom/Religion check to kill parents for non-Selunite Tav
roll_success = "f5518130-384e-4bee-8197-18edd8851774"
roll_failure = "e49c2573-c664-46a3-a188-9e275dece7c5"
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_success, True, "0001265e-7823-7e88-d1d3-bb16e735ac67"))
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_failure, False, "317a6bfd-3788-7ffd-36bb-671d1ad27a14"))
dice_roll = bg3.create_dice_roll_dialog_node(
    "cba612bc-d577-8782-683e-d7797679320d",
    slot_idx_tav, # Tav is in the slot 2
    "Wisdom",
    "Religion",
    bg3.DC_Act3_Hard,
    roll_success,
    roll_failure,
    "hc0077229g09edg4ed4gb446g6e6f48cf2363",
    "1",
    "399407ee-a5f1-4397-a357-12b87ad35b59",
    checkflags=[tag_god_selune_false]
)
d.delete_dialog_node("cba612bc-d577-8782-683e-d7797679320d")
d.add_dialog_node(dice_roll)

# DC 18 Wisdom/Religion check to kill parents for Selunite Tav
roll_success = "85e74239-b3fd-4d09-87a7-9376a9ec6a0a"
roll_failure = "b0fe34c9-33fe-47ac-a289-8b09c7c0d6c3"
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_success, True, "0686e3dc-23d6-4920-df64-2f3bbb9707fd"))
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_failure, False, "317a6bfd-3788-7ffd-36bb-671d1ad27a14"))
dice_roll = bg3.create_dice_roll_dialog_node(
    "6b7c30e5-d0c6-be55-c927-f1d62fc602be",
    slot_idx_tav, # Tav is in the slot 2
    "Wisdom",
    "Religion",
    bg3.DC_Act3_Challenging,
    roll_success,
    roll_failure,
    "h13ebab14g1a05g4971ga118g27bfe03dd22e",
    "1",
    "9db0135a-4706-454d-85e7-7d10e65acaae",
    checkflags=[tag_god_selune_true]
)
d.delete_dialog_node("6b7c30e5-d0c6-be55-c927-f1d62fc602be")
d.add_dialog_node(dice_roll)


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, "Mods/GustavDev/Story/DialogsBinary/Companions/Origin_Moments/LOW_SharGrotto_ParentsFate_OM_Shadowheart_COM.lsf.lsx"))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
##########################################################
# LOW_SharGrotto_ViconiaDefeated_OM_Shadowheart_COM.lsf
##########################################################

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/Origin_Moments/LOW_SharGrotto_ViconiaDefeated_OM_Shadowheart_COM.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

slot_idx_tav = d.get_speaker_slot_index(bg3.GROUP_TAV)
slot_idx_shadowheart = d.get_speaker_slot_index(bg3.GBTP_SHADOWHEART)

loot_viconias_stuff_true = bg3.create_flag_group('Object', ((Loot_Viconias_Stuff, True, slot_idx_tav),))
loot_viconias_stuff_false = bg3.create_flag_group('Object', ((Loot_Viconias_Stuff, False, slot_idx_tav),))
tag_shadowheart_shar_path_true = bg3.create_flag_group('Tag', ((bg3.TAG_SHADOWHEART_SHARPATH, True, slot_idx_shadowheart),))

viconia_node_uuid = '075925ee-5b83-f8ea-d00d-720c57ca6844'
tav_decision_node_uuid = '2db696a0-5f5a-480a-b968-99c8f066ba64'
shadowheart_decision_node_uuid = '135d73e9-bb85-5b14-cb28-41c8773237d3'
kill_her_node_uuid = '300a5cf6-4f96-a4e7-5a1e-58f7b87a5a8f'
kill_viconia_roll_node_uuid = 'cab06c2b-c320-4d0c-ab66-5e57cd6dc5ba'
loot_viconias_stuff_node_uuid = '43e67fa4-d42a-412b-a550-924c98829384'
loot_viconias_stuff_shar_node_uuid = 'a6b331eb-1bbe-4c48-98e0-020cb357ea79'
shadowheart_kills_viconia_node_uuid = 'fbc03324-7fa3-b039-6392-d4ac255c1253'
shadowheart_spares_viconia_node_uuid = 'ae0948ab-4134-9f9b-b93d-9147090354d3'


# These dialogs add options to loot Viconia's stuff without killing her for both Selune and Shar paths

loot_viconias_stuff_node = bg3.create_standard_dialog_node(
    loot_viconias_stuff_node_uuid,
    slot_idx_tav,
    [],
    'ha0b56eb6gbc0bg4535g97efga2b7c2671c58',
    '1',
    '7c3c3233-5a04-447e-9958-f5bfa20eb3cd',
    constructor='TagQuestion',
    checkflags=[loot_viconias_stuff_false],
    setflags=[loot_viconias_stuff_true])
d.add_dialog_node(loot_viconias_stuff_node)

d.patch_dialog_append_child(viconia_node_uuid, loot_viconias_stuff_node_uuid, index=0)
d.patch_dialog_append_child(tav_decision_node_uuid, loot_viconias_stuff_node_uuid, index=0)
d.patch_dialog_append_child(shadowheart_decision_node_uuid, loot_viconias_stuff_node_uuid, index=0)

# When on Selune path, Shadowheart doesn't want to follow what Viconia taught her; it will require some persuasion to make her kill Viconia.
roll_success = '7f46e9c4-36a5-40d2-9631-f997cc4229b4'
roll_failure = 'ab99b119-5d36-4ce7-857c-626b7cd2a474'
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_success, True, shadowheart_kills_viconia_node_uuid))
d.add_dialog_node(bg3.create_dice_roll_result_node(roll_failure, False, shadowheart_spares_viconia_node_uuid))
kill_viconia_roll_node = bg3.create_dice_roll_dialog_node(
    kill_viconia_roll_node_uuid,
    slot_idx_tav,
    "Wisdom",
    "Religion",
    bg3.DC_Act3_Hard,
    roll_success,
    roll_failure,
    "h78558948gae13g4d46g936dgf47d53d9fbaf",
    "2",
    "35ee708d-e960-48bc-b95f-1bc290e6e1be")
d.add_dialog_node(kill_viconia_roll_node)

d.patch_dialog_remove_child(shadowheart_decision_node_uuid, kill_her_node_uuid)
d.patch_dialog_append_child(shadowheart_decision_node_uuid, kill_viconia_roll_node_uuid)

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, "Mods/GustavDev/Story/DialogsBinary/Companions/Origin_Moments/LOW_SharGrotto_ViconiaDefeated_OM_Shadowheart_COM.lsf.lsx"))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
###########################################
# Minthara_InParty.lsf
###########################################

###########################################
# Minthara about copmpanions
###########################################
lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/Minthara_InParty.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# I'm curious to hear your thoughts about our companions.
d.patch_dialog_node_attributes('9b0f15eb-4dfd-011a-964f-b9b8c4c596d5', remove_attrs=["ShowOnce"])

# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, "Mods/GustavDev/Story/DialogsBinary/Companions/Minthara_InParty.lsf.lsx"))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

lsf = t.unpack('Gustav', 'Mods/GustavDev/Story/DialogsBinary/Companions/Minthara_InParty_Nested_PartyMemberThoughts.lsf')
lsx = t.convert_lsf_to_lsx(lsf)
d = bg3.bg3_game_object_dialog(lsx)

# I'm curious to hear what you think of Shadowheart.

d.patch_dialog_node_attributes('c390d470-6d3d-4605-bf2b-03a75e72ca1c', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('c390d470-6d3d-4605-bf2b-03a75e72ca1c', setflags=[])

# How do you and Lae'zel get along?
d.patch_dialog_node_attributes('d96b1c54-8903-4eac-9976-b44b8984aad3', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('d96b1c54-8903-4eac-9976-b44b8984aad3', setflags=[])

# What do you make of Astarion?
d.patch_dialog_node_attributes('ff494699-3d8a-4333-a709-27f6b3796dfc', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('ff494699-3d8a-4333-a709-27f6b3796dfc', setflags=[])

# Have you spent much time with Gale?
d.patch_dialog_node_attributes('03bdf98e-ab18-4452-b88a-6921f0755ff1', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('03bdf98e-ab18-4452-b88a-6921f0755ff1', setflags=[])

# Any thoughts on Wyll?
d.patch_dialog_node_attributes('62ca8389-3502-4c56-8164-4130eafcb737', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('62ca8389-3502-4c56-8164-4130eafcb737', setflags=[])

# You and Karlach seem to be friendly.
d.patch_dialog_node_attributes('ad478103-114e-4250-8afa-05141b3627fc', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('ad478103-114e-4250-8afa-05141b3627fc', setflags=[])

# What do you make of Jaheira?
d.patch_dialog_node_attributes('4d323bd3-8403-4246-ae83-0db89ab5689b', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('4d323bd3-8403-4246-ae83-0db89ab5689b', setflags=[])

# You and Minsc are unusual allies.
d.patch_dialog_node_attributes('3e3e6869-d30a-4bf9-831c-54847a77dfdc', remove_attrs=["ShowOnce"])
d.patch_dialog_node_flags('3e3e6869-d30a-4bf9-831c-54847a77dfdc', setflags=[])

# Leave
d.patch_dialog_node_attributes('aad7d24d-8576-40d0-93ac-73d045054069', remove_attrs=["ShowOnce"])


# Save patched dialog
patched_lsx = d.save_to(os.path.join(mod_path, "Mods/GustavDev/Story/DialogsBinary/Companions/Minthara_InParty_Nested_PartyMemberThoughts.lsf.lsx"))
patched_lsf = t.convert_lsx_to_lsf(patched_lsx)

if review:
    patched_lsx = t.convert_lsf_to_lsx(patched_lsf)

# %%
###########################################
# Create .pak file
###########################################
t.pack(mod_path, os.path.join(e.output_path, mod_name + '.pak'))
# Out:
# 'E:\\bg3_modding\\src\\ReallyShadowheart\\env\\out\\ReallyShadowheart.pak'
